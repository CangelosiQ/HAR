# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC, LinearSVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
import datetime
import pickle
import os
import sys
sys.path.append('./..')
import Sammy

# %%
import imp
imp.reload(Sammy)
# Out:
# <module 'Sammy' from 'C:\\Users\\Quentin\\Documents\\INSA\\5GMM\\HAR\\Sammy.py'>

# %%
Xtrain=pd.read_table("X_train.txt",sep='\s+',header=None)
ytrain=pd.read_table("y_train.txt",sep='\s+',header=None,names=('y'))
Xtest=pd.read_table("X_test.txt",sep='\s+',header=None)
ytest=pd.read_table("y_test.txt",sep='\s+',header=None,names=('y'))
ytrain=ytrain["y"]
ytest=ytest["y"]
LABELS = ["WALKING","WALKING UPSTAIRS","WALKING DOWNSTAIRS","SITTING","STANDING","LAYING"]

scaler=StandardScaler()
scaler.fit(Xtrain)
Xtrain=scaler.transform(Xtrain)
Xtest=scaler.transform(Xtest)

path='./results/ResultsXGB.pickle'
if os.path.exists(path):
    Resultats=pickle.load(open(path, 'rb'))
else:
    Resultats=Sammy.Results()

Resultats.say_hello()
# Out:
# Welcome back, I am Sammy Nimizz.
# I have already run 12 models and got a best score of 9.385e-01.
#  May I help you? (I am 7336 secondes old)

# %% [markdown]
# # Optimisation

# %%
#Resultats.basic_tour(Xtrain,ytrain)
#Resultats.run(Xtrain,ytrain,method,param)
Resultats.random_start(Xtrain,ytrain, nb_run=50,methods=XGBClassifier)
#Resultats.optimize(Xtrain,ytrain,nb_epoch=2,method=LogisticRegression,goal='max',coef_selection=0.2)
f=open('./results/ResultsXGB.pickle', 'wb')
pickle.dump(Resultats,f)
f.close()
print(datetime.datetime.now())
# Out:
# Run 1/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 14, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.261e-01
#
# Run 2/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 2, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.416e-01
#
# Run 3/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 50, 'min_child_weight': 1, 'max_depth': 4, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.296e-01
#
# Run 4/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 9, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.319e-01
#
# Run 5/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 250, 'min_child_weight': 1, 'max_depth': 10, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.334e-01
#
# Run 6/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 10, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.318e-01
#
# Run 7/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 250, 'min_child_weight': 1, 'max_depth': 11, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.315e-01
#
# Run 8/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 50, 'min_child_weight': 1, 'max_depth': 5, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.299e-01
#
# Run 9/50
# Run 10/50
# Run 11/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 13, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.308e-01
#
# Run 12/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 150, 'min_child_weight': 1, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.421e-01
#
# Run 13/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 250, 'min_child_weight': 1, 'max_depth': 5, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.397e-01
#
# Run 14/50
# Run 15/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 250, 'min_child_weight': 1, 'max_depth': 7, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.314e-01
#
# Run 16/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 50, 'min_child_weight': 1, 'max_depth': 7, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.202e-01
#
# Run 17/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 250, 'min_child_weight': 1, 'max_depth': 4, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.414e-01
#
# Run 18/50
# Run 19/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 12, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.310e-01
#
# Run 20/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 150, 'min_child_weight': 1, 'max_depth': 7, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.288e-01
#
# Run 21/50
# Run 22/50
# Run 23/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 150, 'min_child_weight': 1, 'max_depth': 9, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.306e-01
#
# Run 24/50
# Run 25/50
# Run 26/50
# Run 27/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 250, 'min_child_weight': 1, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.454e-01
#
# Run 28/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 150, 'min_child_weight': 1, 'max_depth': 6, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.338e-01
#
# Run 29/50
# Run 30/50
# Run 31/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 8, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.319e-01
#
# Run 32/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 150, 'min_child_weight': 1, 'max_depth': 14, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.295e-01
#
# Run 33/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 150, 'min_child_weight': 1, 'max_depth': 4, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.394e-01
#
# Run 34/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.446e-01
#
# Run 35/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 11, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.296e-01
#
# Run 36/50
# Run 37/50
# Run 38/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 50, 'min_child_weight': 1, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.269e-01
#
# Run 39/50
# Run 40/50
# Run 41/50
# Run 42/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 50, 'min_child_weight': 1, 'max_depth': 9, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.238e-01
#
# Run 43/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 7, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.307e-01
#
# Run 44/50
# Run 45/50
# Run 46/50
# Run 47/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 250, 'min_child_weight': 1, 'max_depth': 8, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.336e-01
#
# Run 48/50
# Running XGBClassifier with parameters: {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 150, 'min_child_weight': 1, 'max_depth': 13, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# Score: 9.293e-01
#
# Run 49/50
# Run 50/50
# 2017-12-14 03:47:52.146950

# %%
#Resultats.basic_tour(Xtrain,ytrain)
#Resultats.run(Xtrain,ytrain,method,param)
Resultats.random_start(Xtrain,ytrain, nb_run=30,methods=XGBClassifier)
#Resultats.optimize(Xtrain,ytrain,nb_epoch=2,method=LogisticRegression,goal='max',coef_selection=0.2)
f=open('./results/ResultsXGB.pickle', 'wb')
pickle.dump(Resultats,f)
f.close()
print(datetime.datetime.now())
# Out:
# Run 1/30
# Run 2/30
# Run 3/30
# Run 4/30
# Run 5/30
# Run 6/30
# Run 7/30
# Run 8/30
# Run 9/30
# Run 10/30
# Run 11/30
# Run 12/30
# Run 13/30
# Run 14/30
# Run 15/30
# Run 16/30
# Run 17/30
# Run 18/30
# Run 19/30
# Run 20/30
# Run 21/30
# Run 22/30
# Run 23/30
# Run 24/30
# Run 25/30
# Run 26/30
# Run 27/30
# Run 28/30
# Run 29/30
# Run 30/30
# 2017-12-13 07:33:43.963891

# %% [markdown]
# ## Meilleurs résultats

# %%
print(Sammy.Results(Resultats.bests(nb=10)))
# Out:
# 10 Results:
# XGBClassifier:
# Parameters:
# {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 250, 'min_child_weight': 1, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# CV Score:   9.454e-01
#
# XGBClassifier:
# Parameters:
# {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# CV Score:   9.446e-01
#
# XGBClassifier:
# Parameters:
# {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 150, 'min_child_weight': 1, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# CV Score:   9.421e-01
#
# XGBClassifier:
# Parameters:
# {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 2, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# CV Score:   9.416e-01
#
# XGBClassifier:
# Parameters:
# {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 250, 'min_child_weight': 1, 'max_depth': 4, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# CV Score:   9.414e-01
#
# XGBClassifier:
# Parameters:
# {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 250, 'min_child_weight': 1, 'max_depth': 5, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# CV Score:   9.397e-01
#
# XGBClassifier:
# Parameters:
# {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 150, 'min_child_weight': 1, 'max_depth': 4, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# CV Score:   9.394e-01
#
# XGBClassifier:
# Parameters:
# {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# CV Score:   9.385e-01
#
# XGBClassifier:
# Parameters:
# {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 4, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# CV Score:   9.368e-01
#
# XGBClassifier:
# Parameters:
# {'subsample': 1, 'silent': True, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'objective': 'multi:softmax', 'nthread': None, 'n_jobs': 4, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 5, 'max_delta_step': 0, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}
# CV Score:   9.340e-01

# %%
print(Resultats.sort())
# Out:
# 159 Results:
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.35000000000000003}
# Score: 3.868e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.70000000000000007}
# Score: 4.272e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.40000000000000002}
# Score: 4.797e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.15000000000000002}
# Score: 5.146e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.90000000000000002}
# Score: 5.403e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.20000000000000001}
# Score: 5.456e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.35000000000000003}
# Score: 5.640e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 45.605000000000004}
# Score: 6.578e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.55000000000000004}
# Score: 6.625e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 95.055000000000007}
# Score: 6.895e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.85000000000000009}
# Score: 7.191e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 100.0}
# Score: 7.593e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 95.055000000000007}
# Score: 7.596e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 60.440000000000005}
# Score: 7.611e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 85.164999999999992}
# Score: 7.613e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 90.109999999999999}
# Score: 7.613e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 70.329999999999998}
# Score: 7.615e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 50.550000000000004}
# Score: 7.619e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 50.550000000000004}
# Score: 7.619e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 55.495000000000005}
# Score: 7.619e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 40.660000000000004}
# Score: 7.642e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 40.660000000000004}
# Score: 7.642e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 25.825000000000003}
# Score: 7.669e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 25.825000000000003}
# Score: 7.669e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 25.825000000000003}
# Score: 7.669e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 35.715000000000003}
# Score: 7.672e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 35.715000000000003}
# Score: 7.672e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 15.935}
# Score: 7.687e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 60.440000000000005}
# Score: 7.704e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 100.0}
# Score: 7.729e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 6.0449999999999999}
# Score: 7.751e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 6.0449999999999999}
# Score: 7.751e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.25}
# Score: 7.844e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 55.495000000000005}
# Score: 8.035e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.95000000000000007}
# Score: 8.095e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 1.0}
# Score: 8.101e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# Score: 8.104e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# Score: 8.104e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# Score: 8.104e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# Score: 8.104e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.90000000000000002}
# Score: 8.107e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.90000000000000002}
# Score: 8.107e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.55000000000000004}
# Score: 8.157e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.35000000000000003}
# Score: 8.198e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.30000000000000004}
# Score: 8.209e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.40000000000000002}
# Score: 8.218e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.25}
# Score: 8.231e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.25}
# Score: 8.231e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 35.715000000000003}
# Score: 8.241e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.20000000000000001}
# Score: 8.280e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.20000000000000001}
# Score: 8.280e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.45000000000000001}
# Score: 8.290e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 6.0449999999999999}
# Score: 8.337e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.10000000000000001}
# Score: 8.369e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.10000000000000001}
# Score: 8.369e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.050000000000000003}
# Score: 8.466e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.35000000000000003}
# Score: 8.490e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.40000000000000002}
# Score: 8.546e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# Score: 8.684e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 1.1000000000000001}
# Score: 8.715e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 25.825000000000003}
# Score: 8.733e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.050000000000000003}
# Score: 8.764e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.050000000000000003}
# Score: 8.764e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 80.219999999999999}
# Score: 8.852e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.10000000000000001}
# Score: 8.990e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.15000000000000002}
# Score: 9.118e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.45000000000000001}
# Score: 9.127e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.5}
# Score: 9.141e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 45.605000000000004}
# Score: 9.175e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 80.219999999999999}
# Score: 9.188e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.65000000000000002}
# Score: 9.204e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.75}
# Score: 9.218e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.25}
# Score: 9.220e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.30000000000000004}
# Score: 9.239e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.75}
# Score: 9.244e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.40000000000000002}
# Score: 9.280e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.40000000000000002}
# Score: 9.280e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.40000000000000002}
# Score: 9.280e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.40000000000000002}
# Score: 9.280e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.45000000000000001}
# Score: 9.301e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.45000000000000001}
# Score: 9.301e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 85.164999999999992}
# Score: 9.315e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.60000000000000009}
# Score: 9.333e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.65000000000000002}
# Score: 9.348e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.65000000000000002}
# Score: 9.348e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.70000000000000007}
# Score: 9.353e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.75}
# Score: 9.361e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.75}
# Score: 9.361e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.75}
# Score: 9.361e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.75}
# Score: 9.361e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.75}
# Score: 9.361e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.90000000000000002}
# Score: 9.363e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# Score: 9.365e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# Score: 9.365e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# Score: 9.365e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.95000000000000007}
# Score: 9.367e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 1.1000000000000001}
# Score: 9.376e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 20.880000000000003}
# Score: 9.429e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 20.880000000000003}
# Score: 9.429e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 25.825000000000003}
# Score: 9.432e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 6.0449999999999999}
# Score: 9.435e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 30.770000000000003}
# Score: 9.435e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 30.770000000000003}
# Score: 9.435e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 80.219999999999999}
# Score: 9.435e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 90.109999999999999}
# Score: 9.435e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 90.109999999999999}
# Score: 9.435e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 75.275000000000006}
# Score: 9.435e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 75.275000000000006}
# Score: 9.435e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 100.0}
# Score: 9.435e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 100.0}
# Score: 9.435e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 85.164999999999992}
# Score: 9.435e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 35.715000000000003}
# Score: 9.435e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 6.0449999999999999}
# Score: 9.453e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 6.0449999999999999}
# Score: 9.453e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 6.0449999999999999}
# Score: 9.453e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 1.1000000000000001}
# Score: 9.458e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 1.1000000000000001}
# Score: 9.458e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 90.109999999999999}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 15.935}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 100.0}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 60.440000000000005}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 55.495000000000005}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 100.0}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 95.055000000000007}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 95.055000000000007}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 65.384999999999991}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 90.109999999999999}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 100.0}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 75.275000000000006}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 25.825000000000003}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 70.329999999999998}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 100.0}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 95.055000000000007}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 45.605000000000004}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 15.935}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 40.660000000000004}
# Score: 9.460e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 1.0}
# Score: 9.461e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.90000000000000002}
# Score: 9.466e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.90000000000000002}
# Score: 9.466e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 10, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.95000000000000007}
# Score: 9.468e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.60000000000000009}
# Score: 9.469e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# Score: 9.469e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# Score: 9.469e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# Score: 9.469e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.55000000000000004}
# Score: 9.472e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.65000000000000002}
# Score: 9.472e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.10000000000000001}
# Score: 9.473e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.25}
# Score: 9.474e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.75}
# Score: 9.474e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.75}
# Score: 9.474e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 7, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.25}
# Score: 9.476e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.15000000000000002}
# Score: 9.480e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.35000000000000003}
# Score: 9.481e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.30000000000000004}
# Score: 9.483e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.30000000000000004}
# Score: 9.483e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 8, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.20000000000000001}
# Score: 9.485e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 6, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.20000000000000001}
# Score: 9.485e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.20000000000000001}
# Score: 9.485e-01
#
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.20000000000000001}
# Score: 9.485e-01

# %%
Resultats.test(Xtrain, ytrain, Xtest, ytest, nb_test=5)
# Out:
# Testing LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l1', 'multi_class': 'ovr', 'loss': 'squared_hinge', 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.0}
# Test Score= 0.961316593146
# Testing LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr', 'loss': 'squared_hinge', 'intercept_scaling': 1, 'fit_intercept': False, 'dual': True, 'class_weight': None, 'C': 6.5}
# Test Score= 0.949100780455
# Testing LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr', 'loss': 'squared_hinge', 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 1.0}
# Test Score= 0.964370546318
# Testing LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr', 'loss': 'squared_hinge', 'intercept_scaling': 1, 'fit_intercept': False, 'dual': True, 'class_weight': None, 'C': 0.75}
# Test Score= 0.951136749237
# Testing LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr', 'loss': 'squared_hinge', 'intercept_scaling': 1, 'fit_intercept': False, 'dual': False, 'class_weight': None, 'C': 2.75}
# Test Score= 0.945028842891
