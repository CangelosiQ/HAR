# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC, LinearSVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
import pickle
import os
import Sammy

# %%
import imp
imp.reload(Sammy)
# Out:
# <module 'Sammy' from 'C:\\Users\\Quentin\\Documents\\INSA\\5GMM\\HAR\\Sammy.py'>

# %%
Xtrain=pd.read_table("X_train.txt",sep='\s+',header=None)
ytrain=pd.read_table("y_train.txt",sep='\s+',header=None,names=('y'))
Xtest=pd.read_table("X_test.txt",sep='\s+',header=None)
ytest=pd.read_table("y_test.txt",sep='\s+',header=None,names=('y'))
ytrain=ytrain["y"]
ytest=ytest["y"]
LABELS = ["WALKING","WALKING UPSTAIRS","WALKING DOWNSTAIRS","SITTING","STANDING","LAYING"]

scaler=StandardScaler()
scaler.fit(Xtrain)
Xtrain=scaler.transform(Xtrain)
Xtest=scaler.transform(Xtest)

path='./results/Resultats.pickle'
if os.path.exists(path):
    Resultats=pickle.load(open(path, 'rb'))
else:
    Resultats=Sammy.Results()
Resultats.say_hello()
# Out:
# Welcome back, I am Sammy Nimizz.
# I have already run 55 models and got a best score of 9.530e-01.
#  May I help you? (I am 7762 secondes old)

# %% [markdown]
# # Optimisation

# %%
Resultats.optimize(Xtrain,ytrain,nb_epoch=2,method=LogisticRegression,goal='max',coef_selection=0.2)
f=open('./results/Resultats.pickle', 'wb')
pickle.dump(Resultats,f)
f.close()
# Out:
# I want to improve myself!
# I am too young to be optimized, let me try some randomness first.
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 3.0}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 3.0}
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Score: 9.367e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 3.0}
# Score: 9.367e-01
# Adding result
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'newton-cg', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 1.5}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'newton-cg', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 1.5}
# An error occured with this configuration.<class 'ValueError'>
#
# Adding wrong config
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 5.5}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 5.5}
# An error occured with this configuration.<class 'ValueError'>
#
# Adding wrong config
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 9.5}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 9.5}
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Score: 9.366e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 9.5}
# Score: 9.366e-01
# Adding result
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 6.5}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 6.5}
# An error occured with this configuration.<class 'ValueError'>
#
# Adding wrong config
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 3.0}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 3.0}
# Score: 9.475e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 3.0}
# Score: 9.475e-01
# Adding result
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 6.0}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 6.0}
# An error occured with this configuration.<class 'ValueError'>
#
# Adding wrong config
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 6.5}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 6.5}
# An error occured with this configuration.<class 'ValueError'>
#
# Adding wrong config
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 7.5}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 7.5}
# Score: 9.453e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 7.5}
# Score: 9.453e-01
# Adding result
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 6.5}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 6.5}
# An error occured with this configuration.<class 'ValueError'>
#
# Adding wrong config
#
#
# Epoch 1
# sorting 8 results
# 8 results are sorted
#
# I selected the 2 best solutions I know.
# 2 Results:
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.0}
# Score: 9.523e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# Score: 9.513e-01
#
# Selection:
#
#
# Mutation!
# Evaluation...
# Method is new? False
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.0}
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Score: 9.367e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# Score: 9.367e-01
# Adding result
#
#
# Epoch 2
# sorting 9 results
# 9 results are sorted
#
# I selected the 2 best solutions I know.
# 2 Results:
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.0}
# Score: 9.523e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# Score: 9.513e-01
#
# Selection:
#
#
# Mutation!
# Evaluation...
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.0}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.0}
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Score: 9.367e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.0}
# Score: 9.367e-01
# Adding result
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# Score: 9.468e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# Score: 9.468e-01
# Adding result

# %%
#Resultats.run(Xtrain,ytrain,method,param)
Resultats.random_start(Xtrain,ytrain,nb_run=20,methods=LogisticRegression)
f=open('./results/Resultats.pickle', 'wb')
pickle.dump(Resultats,f)
f.close()
# Out:
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 2.0}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 2.0}
# An error occured with this configuration.<class 'ValueError'>
#
# Adding wrong config
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 6.0}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 6.0}
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Score: 9.348e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 6.0}
# Score: 9.348e-01
# Adding result
#
# Method is new? False
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 3.0}
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.5}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.5}
# Score: 9.461e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.5}
# Score: 9.461e-01
# Adding result
#
# Method is new? False
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'newton-cg', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 9.0}
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 7.5}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 7.5}
# An error occured with this configuration.<class 'ValueError'>
#
# Adding wrong config
#
# Method is new? True
#  <class 'sklearn.linear_model.logistic.LogisticRegression'> {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 6.0}
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 6.0}

# %% [markdown]
# ## Meilleurs résultats

# %%
print(Sammy.Results(Resultats.bests(nb=5)))
# Out:
# 5 Results:
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 1.5}
# Score: 9.530e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 1.0}
# Score: 9.529e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.0}
# Score: 9.523e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# Score: 9.513e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 3.5}
# Score: 9.507e-01

# %%
print(Resultats.sort())
# Out:
# sorting 55 results
# 55 results are sorted
#
# 55 Results:
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 3.0}
# Score: 9.319e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.5}
# Score: 9.321e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 1.0}
# Score: 9.321e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 7.5}
# Score: 9.321e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.0}
# Score: 9.348e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 3.5}
# Score: 9.349e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 1.5}
# Score: 9.351e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 9.5}
# Score: 9.366e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 9.0}
# Score: 9.366e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# Score: 9.367e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.0}
# Score: 9.367e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 3.0}
# Score: 9.367e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 7.0}
# Score: 9.367e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 8.0}
# Score: 9.368e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 3.5}
# Score: 9.370e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 8.0}
# Score: 9.449e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 6.0}
# Score: 9.450e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 7.5}
# Score: 9.453e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 6.5}
# Score: 9.453e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 8.5}
# Score: 9.455e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.0}
# Score: 9.458e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 0.5}
# Score: 9.461e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 0.5}
# Score: 9.462e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'newton-cg', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.5}
# Score: 9.465e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 9.5}
# Score: 9.465e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 9.0}
# Score: 9.465e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 8.5}
# Score: 9.465e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 1.0}
# Score: 9.468e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'newton-cg', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 6.0}
# Score: 9.468e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 7.5}
# Score: 9.468e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# Score: 9.468e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'newton-cg', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 1.5}
# Score: 9.469e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.0}
# Score: 9.469e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 6.0}
# Score: 9.469e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 3.0}
# Score: 9.470e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.5}
# Score: 9.470e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 7.5}
# Score: 9.473e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 5.0}
# Score: 9.473e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 5.0}
# Score: 9.475e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 3.0}
# Score: 9.475e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 1.5}
# Score: 9.476e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 7.0}
# Score: 9.476e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 6.5}
# Score: 9.480e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 8.5}
# Score: 9.484e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 8.0}
# Score: 9.487e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 9.5}
# Score: 9.492e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 7.0}
# Score: 9.496e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 8.5}
# Score: 9.499e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.0}
# Score: 9.503e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 5.5}
# Score: 9.504e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 3.5}
# Score: 9.507e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# Score: 9.513e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.0}
# Score: 9.523e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 1.0}
# Score: 9.529e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 1.5}
# Score: 9.530e-01

# %%
Resultats.test(Xtrain, ytrain, Xtest, ytest, nb_test=5)
# Out:
# Testing LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 1.5}
# Test Score= 0.960298608755
# Testing LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 1.0}
# Test Score= 0.959959280624
# Testing LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 2.0}
# Test Score= 0.959959280624
# Testing LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 4.5}
# Test Score= 0.963013233797
# Testing LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'liblinear', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 100, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 3.5}
# Test Score= 0.964031218188
