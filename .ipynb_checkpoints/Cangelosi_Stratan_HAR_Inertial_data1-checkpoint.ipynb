# %% [markdown]
# <center>
# <a href="http://www.insa-toulouse.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/logo-insa.jpg" style="float:left; max-width: 120px; display: inline" alt="INSA"/></a>
#
# <a href="http://wikistat.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/wikistat.jpg" style="max-width: 250px; display: inline"  alt="Wikistat"/></a>
#
# <a href="http://www.math.univ-toulouse.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/logo_imt.jpg" style="float:right; max-width: 200px; display: inline" alt="IMT"/> </a>
# </center>

# %% [markdown]
# # [Ateliers: Technologies des grosses data](https://github.com/wikistat/Ateliers-Big-Data)

# %% [markdown]
# # [Reconnaissance d'Activité Humaine](https://github.com/wikistat/Ateliers-Big-Data/5-HumanActivityRecognition) ([*HAR*](https://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones)) en <a href="https://www.python.org/"><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Python_logo_and_wordmark.svg/390px-Python_logo_and_wordmark.svg.png" style="max-width: 120px; display: inline" alt="Python"/></a>
# ##  Seconde partie:  étude des signaux bruts - Exploration et Apprentissage (profond) des signaux bruts  avec <a href="https://keras.io/"><img src="https://s3.amazonaws.com/keras.io/img/keras-logo-2018-large-1200.png" style="max-width: 100px; display: inline" alt="Keras"/></a>

# %% [markdown]
# ## Sommaire
#         1 Introduction
#             1.1 Contexte
#             1.2 Objectifs
#             1.3 Travail à réaliser
#             1.4 Librairies
#             1.5 Prise en charge des données
#             1.6 Visualisations
#
#         2 Exploration
#             2.1 Analyse en composantes principales
#                 a. Sur un Signal
#                 b. Sur tous les signaux
#             2.2 Analyse factorielle discriminante
#                 a. Sur un signal
#                 b.  Sur tous les signaux
#             2.3 Coefficients dans une base d'ondelettes
#             2.4 Analyse en composantes principales sur les coefficients d'ondelettes
#                 a. Ondelettes de niveau le plus fin J=7
#                 b. coefficients des niveaux J=0 à  6
#                 c. coefficients seuillés
#
#         3 Apprentissage des signaux uni-dimensionels
#             3.1 Régression Logistique
#                 a. Sur données brutes
#                 b. Sur coefficients d'ondelettes
#             3.2 Analyse Discriminante Linéaire
#                 a. Sur données brutes
#                 b. Sur coefficients d'ondelettes
#             3.3 Perceptron multicouche
#
#         4 Apprentissage des signaux multidimensionnels
#             4.1 Perceptron multichouche
#             4.2 *Long Short Time Memory (LSTM)*
#             3.3 Réseau avec couche convolutionelle 1D (*ConvNet*)
#             4.3 Réseau avec couche convolutionelle 2D (*ConvNet*)
#
#
# Méthode | Score Test données brutes | Score Test coefs ondelettes | Coefficients
# --|--
# Régression Logistique | 0.609 | 0.651 | seuillés
# Analyse Discriminante Linéaire | 0.588 | 0.660 | seuillés
# Analyse Discriminante Quadratique | 0.443 | 0.716 | niveau 7
# SVM Linéaire| 0.607 | 0.663 | seuillés
# SVM Gaussien| 0.900 | 0.822 | niveaux 1 à 6
# Gradient Boosting| 0.916 | 0.904 | tous
# RandomForest| 0.883 | 0.936 | seuillés
# XGBoost| 0.922 | 0.867 | niveaux 1 à 6
# Perceptron Multicouche | 0.889 | 0.868 | niveaux 1 à 6
#
# Méthode | Score Test données brutes
# --|--
# Perceptron Multicouche | 0.
# LSTM | 0.
# NN Conv1D | 0.
# NN Conv2D | 0.

# %% [markdown]
# ##  1 Introduction
# ### 1.1  Contexte
# Les données sont issues de la communauté qui vise la reconnaissance d'activités humaines (*Human activity recognition, HAR*) à partir d’enregistrements, par exemple du gyroscope et de l'accéléromètre d'un smartphone, objet connecté précurseur et dont la fonctionnalité de téléphonie devient très secondaire.
# Voir à ce propos l'[article](https://www.elen.ucl.ac.be/Proceedings/esann/esannpdf/es2013-11.pdf) relatant un colloque de 2013.
#
# Les données publiques disponibles et largement étudiées ont été acquises, décrites et analysées par [Anguita et al. (2013)]().
# Elles sont accessibles sur le [dépôt](https://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones) de l'University California Irvine (UCI) consacré à l'apprentissage machine ainsi que sur le site *Kaggle*.
#
# L'archive contient les données brutes: accélérations en x, y, et z, chacun de 128 colonnes. D'autres fichiers en y soustrayant la gravité naturelle ainsi que les accélérations angulaires en x, y, et z soit en tout 9 fichiers. Mais 6 utiles avec 6*128=768 mesures.
#
# C'est sur ces données brutes que nous allons appliquer des méthodes d'apprentissage
#
# Les méthodes d'apprentissage sont appliquées sur ces données brutes, sans calculs préliminaires de caractéristiques (*features*).
#
# ### 1.2 Objectifs
# Cette deuxième étape s'intéresse aux données brutes. Est-il possible d'économiser le travail préliminaire de définition des variables métier en utilisant par exemple les ressources de décompositions systématiques sur une base d'ondelette ou un algorihtme d'apprentissage profond? L'enjeu est important, le calcul en temps réel des variables métier consomme beaucoup d'énergie et l'objectif serait de pouvoir embarquer (faire porter) un système économe défini par exemple par un réseau de neurones après son apprentissage.
#
# Comme pour les données métier, l'étude commence par une exploration: affichage et visualisation des données, réduction de dimension.
#
# ### 1.3 Travail à réaliser
# **Attention l'accès à un environnement *GPU* est très vivement conseillé voire indispensable.**
# - Modélisation, prévision de l'échantillon test par
#    - Régression logistique (`Scikit-learn`)
#    - Apprentissage profond en utilisant `Keras`
#        - MLP sur signaux "applatis"
#        - MLP sur signaux mutlidimensionelles
#        - LSTM
#        - 1D Convolution
#        - 2D Convolution
#
# - Ajouter à ce calepin:
#     - Application des méthodes d'apprentissage classique ou non sur les coefficients des décompositions des signaux en ondelettes
#     - optimisation des paramètres des différentes méthodes.
#     - Améliorer l'architexture des réseaux?
#
#
# ### 1.4 Librairies

# %%
import pandas as pd
import numpy as np
import os
import time
import copy
import random
import itertools

#Utils Sklearn
import sklearn.linear_model as lm
from sklearn.metrics import confusion_matrix

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sb
sb.set()
sb.set_style("darkgrid", {"axes.facecolor": ".9"})

import sklearn.decomposition as sdec 
import sklearn.preprocessing as sprep
import sklearn.discriminant_analysis as sda
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from statsmodels.robust import mad

# Hierarchical clustering
import scipy.cluster.hierarchy as sch
# LOF
import sklearn.neighbors as sn
# Isolation Forest
import sklearn.ensemble as se
import sklearn.decomposition as sd
import sklearn.preprocessing as sp

# Plot et Display
from IPython.display import display

import pandas as pd
import numpy as np
import os
import time
import copy
import random
import itertools

#Utils Sklearn
import sklearn.linear_model as lm
from sklearn.metrics import confusion_matrix

# %matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sb
sb.set()

# DEEP LEARING
#import tensorflow as tf
#np.random.seed(42)
#tf.set_random_seed(42)

# for reproducibility
# https://github.com/fchollet/keras/issues/2280
#session_conf = tf.ConfigProto(
#    intra_op_parallelism_threads=1,
#    inter_op_parallelism_threads=1
#)

from keras import backend as K
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
#K.set_session(sess)

import keras.models as km 
import keras.layers as kl 
import keras.layers.core as klc
# Out:
# Using TensorFlow backend.

# %%
#Wavelet
import pywt
from xgboost import XGBClassifier

# %% [markdown]
# ### 1.5 Prise en charge des données
# #### a. Source
#
# Les données sont celles originales du dépôt de l'[UCI](https://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones). Elle peuvent être téléchargées en cliquant [ici](https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip).
#
# Elles contiennent deux jeux de dimensions différentes, chacun partagé en apprentissage et test.
#
# 1. Multidimensionel: un individus est constitué de 9 Séries Temporelles de *dimensions* $(N, 128, 9)$
# 2. Unidimensionnel: Les 9 Séries Temporelles sont concaténées pour constituer un vecteur de 128*9 = 1152 variables de *dimensions* $(N, 1152)*
#
# Deux objets différents sont construits pour définir la variable $Y$ réponse car les librairies `Scikit-learn` et `Keras` prennent en compte des structures différentes:
#
# 1. `Scikit-Learn`  Un vecteur de dimension $(N, 1)$ avec, pour chaque individu le numéro du label de l'activité de 0 à 5.
# 2. `Keras` Une matrice de dimension $(N, 6)$ des indicatrices (0 ou 1) des modalités de $Y$.

# %% [markdown]
# #### b. Structurer les données
# Définir le chemin d'accès aux données puis les fonctions utiles.

# %%
DATADIR_UCI = './../UCI HAR Dataset'
SIGNALS = [ "body_acc_x", "body_acc_y", "body_acc_z", "body_gyro_x", "body_gyro_y", "body_gyro_z", "total_acc_x", "total_acc_y", "total_acc_z"]

def my_read_csv(filename):
    return pd.read_csv(filename, delim_whitespace=True, header=None)

def load_signal(data_dir, subset, signal):
    filename = f'{data_dir}/{subset}/Inertial Signals/{signal}_{subset}.txt'
    x = my_read_csv(filename).as_matrix()
    return x 

def load_signals(data_dir, subset, flatten = False):
    signals_data = []
    for signal in SIGNALS:
        signals_data.append(load_signal(data_dir, subset, signal)) 
    
    if flatten :
        X = np.hstack(signals_data)
    else:
        X = np.transpose(signals_data, (1, 2, 0))
        
    return X 

def load_y(data_dir, subset, dummies = False):
    filename = f'{data_dir}/{subset}/y_{subset}.txt'
    y = my_read_csv(filename)[0]
    
    
    if dummies:
        Y = pd.get_dummies(y).as_matrix()
    else:
        Y = y.as_matrix()
    
    return Y

# %% [markdown]
# Lecture des données

# %%
#Multidimensional Data
X_train, X_test = load_signals(DATADIR_UCI, 'train'), load_signals(DATADIR_UCI, 'test')
# Flattened Data
X_train_flatten, X_test_flatten = load_signals(DATADIR_UCI, 'train', flatten=True), load_signals(DATADIR_UCI, 'test', flatten=True)

# Label Y
Y_train_label, Y_test_label = load_y(DATADIR_UCI, 'train', dummies = False), load_y(DATADIR_UCI, 'test', dummies = False)
#Dummies Y (For Keras)
Y_train_dummies, Y_test_dummies = load_y(DATADIR_UCI, 'train', dummies = True), load_y(DATADIR_UCI, 'test', dummies = True)

N_train = X_train.shape[0]
N_test = X_test.shape[0]

# %% [markdown]
# Vérification des dimensions

# %%
print("Dimension")
print("Données Multidimensionelles, : " + str(X_train.shape))
print("Données Unimensionelles, : " + str(X_train_flatten.shape))
print("Vecteur réponse (scikit-learn) : " + str(Y_train_label.shape))
print("Matrice réponse(Keras) : " + str(Y_train_dummies.shape))
# Out:
# Dimension
# Données Multidimensionelles, : (7352, 128, 9)
# Données Unimensionelles, : (7352, 1152)
# Vecteur réponse (scikit-learn) : (7352,)
# Matrice réponse(Keras) : (7352, 6)

# %% [markdown]
# ### 1.6 Visualisations
# #### a. Fonctions utiles

# %%
CMAP = plt.get_cmap("Accent")
SIGNALS = ["body_acc x", "body_acc y", "body_acc z", 
                "body_gyro x", "body_gyro y", "body_gyro z", 
               "total_acc x", "total_acc y", "total_acc z"] 


ACTIVITY_DIC = {1 : "WALKING",
2 : "WALKING UPSTAIRS",
3 : "WALKING DOWNSTAIRS",
4 : "SITTING",
5 : "STANDING",
6 : "LAYING"}

COLOR_DIC = {1 : "black", 2: "red", 3 : "pink", 4: "orange", 5:'blue', 6:"green"}

def plot_one_axe(X, fig, ax, sample_to_plot, cmap):
    for act,Xgb in X.groupby("Activity"):
        Xgb_first_values = Xgb.values[:sample_to_plot,:-1]
        x = Xgb_first_values[0]
        ax.plot(x, linewidth=1, color=cmap(act-1), label = label_dic[act])
        for x in Xgb_first_values[1:]:
            ax.plot(x, linewidth=1, color=cmap(act-1))

            
def plot_one_axe_shuffle(X, fig, ax, sample_to_plot, cmap):
    plot_data = []
    for act,Xgb in X.groupby("Activity"):
        Xgb_first_values = Xgb.values[:sample_to_plot,:-1]
        x = Xgb_first_values[0]
        ax.plot(x, linewidth=1, color=cmap(act-1), label = label_dic[act])
        for x in Xgb_first_values[1:]:
            plot_data.append([x,cmap(act-1)])
    random.shuffle(plot_data)
    for x,color in plot_data:
        ax.plot(x, linewidth=1, color=color)

LABELS = ["WALKING","WALKING UPSTAIRS","WALKING DOWNSTAIRS","SITTING","STANDING","LAYING"]
ACTIVITIES = {
    0: 'WALKING',
    1: 'WALKING_UPSTAIRS',
    2: 'WALKING_DOWNSTAIRS',
    3: 'SITTING',
    4: 'STANDING',
    5: 'LAYING',
}
def my_confusion_matrix(Y_true, Y_pred):
    Y_true = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_true, axis=1)])
    Y_pred = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_pred, axis=1)])

    return pd.crosstab(Y_true, Y_pred, rownames=['True'], colnames=['Pred'])

def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %% [markdown]
# #### b. Tous les signaux

# %%
sample_to_plot = 50
index_per_act = [list(zip(np.repeat(act, sample_to_plot), np.where(Y_train_label==act)[0][:sample_to_plot])) for act in range(1,7)]
index_to_plot = list(itertools.chain.from_iterable(index_per_act))
random.shuffle(index_to_plot)

fig = plt.figure(figsize=(15,10))
for isignal in range(9):
    ax = fig.add_subplot(3,3,isignal+1)
    for act , i in index_to_plot:
        ax.plot(range(128), X_train[i,:,isignal],color=CMAP(act-1), linewidth=1)
        ax.set_title(SIGNALS[isignal])
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="971">

# %% [markdown]
# #### c. Par signal

# %%
sample_to_plot = 10
isignal = 1
index_per_act_dict = dict([(act, np.where(Y_train_label==act)[0][:sample_to_plot]) for act in range(1,7)])


fig = plt.figure(figsize=(15,8), num=SIGNALS[isignal])
for act , index in index_per_act_dict.items():
    ax = fig.add_subplot(3,2,act)
    for x in X_train[index]:
        ax.plot(range(128), x[:,0],color=CMAP(act-1), linewidth=1)
    ax.set_title(ACTIVITY_DIC[act])
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="971">

# %% [markdown]
# **Q** Observer l'un des signaux, par exemple `Walking upstairs`. Qu'est ce qui fait que, pour ces signaux ou courbes, une métrique euclidienne classique ($L_2$) est inopérante?
#
# **Q** Corrélativement pourquoi est-il intéressant de décomposer un signal dans le domaine des fréquances?

# %%
def plot_pca(X_R, ytrain, fig, ax, nbc, nbc2, label_dic=ACTIVITY_DIC, cmaps = plt.get_cmap("Accent")
):
    for i in range(6):
        xs = X_R[ytrain==i+1,nbc-1]
        ys = X_R[ytrain==i+1, nbc2-1]
        label = label_dic[i+1]
        color = cmaps(i)
        ax.scatter(xs, ys, color=color, alpha=.8, s=10, label=label)
        ax.set_xlabel("PC%d : %.2f %%" %(nbc,pca.explained_variance_ratio_[nbc-1]*100), fontsize=15)
        ax.set_ylabel("PC%d : %.2f %%" %(nbc2,pca.explained_variance_ratio_[nbc2-1]*100), fontsize=15)

# %% [markdown]
# ## 2 Exploration
# ### 2.1 Analyse en composantes principales
# Les ACP ne sont pas réduites. Refaire les calculs après réduction des variables : signaux.
#
# #### a. Sur un Signal

# %%
pca = sdec.PCA()
isignal = 4
signal = SIGNALS[isignal]
print("ACP Sur signal : " +signal)
X_r = pca.fit_transform(X_train[:,:,isignal])
# Out:
# ACP Sur signal : body_gyro y

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1,2,1)
ax.bar(range(10), pca.explained_variance_ratio_[:10]*100, align='center',
        color='grey', ecolor='black')
ax.set_xticks(range(10))
ax.set_ylabel("Variance")
ax.set_title("", fontsize=35)
ax.set_title("Pourcentage de variance expliquée \n par les premières composantes", fontsize=20)

ax = fig.add_subplot(1,2,2)
box=ax.boxplot(X_r[:,0:10],whis=100)
ax.set_title("Distribution des premières composantes", fontsize=20)

fig.suptitle("Résultat ACP sur Signal : " + signal, fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="1080">
# Text(0.5,0.98,'Résultat ACP sur Signal : body_gyro y')

# %% [markdown]
# **Attention**: les diagrammes boîtes sont très perturbés pas les distributions des composantes avec une très forte concentration autour de 0 et énormément de valeurs atypiques. D'où l'utilisation du paramètre `whis=100` pour rallonger les moustaches.

# %%
fig = plt.figure(figsize=(10,10), )
ax = fig.add_subplot(1,1,1)
plot_pca(X_r, Y_train_label,fig ,ax ,1 ,3)
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# #### b. Sur tous les signaux

# %%
pca = sdec.PCA()
print("ACP Sur tous les signaux")
X_r = pca.fit_transform(X_train_flatten)
# Out:
# ACP Sur tous les signaux

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1,2,1)
ax.bar(range(10), pca.explained_variance_ratio_[:10]*100, align='center',
        color='grey', ecolor='black')
ax.set_xticks(range(10))
ax.set_ylabel("Variance")
ax.set_title("", fontsize=35)
ax.set_title("Pourcentage de variance expliqué \n des premières composantes", fontsize=20)

ax = fig.add_subplot(1,2,2)
box=ax.boxplot(X_r[:,0:10])
ax.set_title("Distribution des premières composante", fontsize=20)

fig.suptitle("Résultat ACP sur Signal : " + signal, fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="1079.8166334129219">

# %%
fig = plt.figure(figsize=(10,10), )
ax = fig.add_subplot(1,1,1)
plot_pca(X_r, Y_train_label,fig ,ax ,1 ,3)
# Out:
# <img src="data:image/png;base64,..." width="719.1333111870958">

# %% [markdown]
# ### 2.2 Analyse factorielle discriminante
#
# #### a. Sur un signal

# %%
isignal = 0
signal = SIGNALS[isignal]
print("LDA Sur signal : " +signal)

method = sda.LinearDiscriminantAnalysis() 
lda=method.fit(X_train[:,:,isignal],Y_train_label)
X_r2=lda.transform(X_train[:,:,isignal])

fig = plt.figure(figsize= (20,20))
count = 0
for count,(nbc, nbc2)in enumerate([(1,2), (2,3), (3,4), (1,3), (2,4), (1,4)]) :
    ax = fig.add_subplot(3,3,count+1)
    plot_pca(X_r2, Y_train_label , fig,ax,nbc,nbc2)
plt.legend(loc='upper right', bbox_to_anchor=(1.5, 2.2))
plt.show()
# Out:
# LDA Sur signal : body_acc x
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# <img src="data:image/png;base64,..." width="1439.3832890064698">

# %% [markdown]
# #### b.  Sur tous les signaux

# %%
print("LDA Sur tous les signaux")

method = sda.LinearDiscriminantAnalysis() 
lda=method.fit(X_train_flatten,Y_train_label)
X_r2=lda.transform(X_train_flatten)

fig = plt.figure(figsize= (20,20))
count = 0
for count,(nbc, nbc2)in enumerate([(1,2), (2,3), (3,4), (1,3), (2,4), (1,4)]) :
    ax = fig.add_subplot(3,3,count+1)
    plot_pca(X_r2, Y_train_label , fig,ax,nbc,nbc2)
plt.legend(loc='upper right', bbox_to_anchor=(1.5, 2.2))
plt.show()
# Out:
# LDA Sur tous les signaux
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# <img src="data:image/png;base64,..." width="1439.3832890064698">

# %% [markdown]
# ### 2.3 Coefficients dans une base d'ondelettes

# %%
wf = "haar"

Coeff = []
TCoeff = []
for x in X_train_flatten:
    #Apply wabvelet decomposition
    coeffs = pywt.wavedec(x,wf,level=8)
    coeffs_flatten = np.hstack(coeffs)
    Coeff.append(coeffs_flatten)
    # Compute universal Threshold http://jseabold.net/blog/2012/02/23/wavelet-regression-in-python/
    sigma = mad(coeffs[-1])
    uthresh = sigma*np.sqrt(2*np.log(256))
    # Apply Threshold on 4 fist level
    coeffs_thresh = [pywt.threshold(c, uthresh, mode="hard") if i<=3 else c for i,c in enumerate(coeffs[::-1])]
    coeffs_thresh_flatten = np.hstack(coeffs_thresh[::-1])
    TCoeff.append(coeffs_thresh_flatten)
    
Coeff = np.array(Coeff)
TCoeff = np.array(TCoeff)
print(Coeff.shape, TCoeff.shape)
print(np.sum(Coeff!=0), np.sum(TCoeff!=0))
# Out:
# (7352, 1153) (7352, 1153)
# 8469473 1894624

# %%
r,c=Coeff.shape
Coeff_train = Coeff
Coeff_train_n7= Coeff[:,round(c/2):]
Coeff_train_n1_6= Coeff[:,:round(c/2)]
TCoeff_train = TCoeff

# %%
wf = "haar"

Coeff = []
TCoeff = []
for x in X_test_flatten:
    #Apply wabvelet decomposition
    coeffs = pywt.wavedec(x,wf,level=8)
    coeffs_flatten = np.hstack(coeffs)
    Coeff.append(coeffs_flatten)
    # Compute universal Threshold http://jseabold.net/blog/2012/02/23/wavelet-regression-in-python/
    sigma = mad(coeffs[-1])
    uthresh = sigma*np.sqrt(2*np.log(256))
    # Apply Threshold on 4 fist level
    coeffs_thresh = [pywt.threshold(c, uthresh, mode="hard") if i<=3 else c for i,c in enumerate(coeffs[::-1])]
    coeffs_thresh_flatten = np.hstack(coeffs_thresh[::-1])
    TCoeff.append(coeffs_thresh_flatten)
    
Coeff = np.array(Coeff)
TCoeff = np.array(TCoeff)
print(Coeff.shape, TCoeff.shape)
print(np.sum(Coeff!=0), np.sum(TCoeff!=0))
# Out:
# (2947, 1153) (2947, 1153)
# 3394933 768232

# %%
Coeff_test = Coeff
Coeff_test_n7= Coeff[:,round(c/2):]
Coeff_test_n1_6= Coeff[:,:round(c/2)]
TCoeff_test = TCoeff

# %% [markdown]
# ### 2.4 Analyse en composantes principales sur les coefficients d'ondelettes

# %% [markdown]
# #### a. Ondelettes de niveau le plus fin J=7

# %%
acp3 = sd.PCA()
X_acp3 = acp3.fit_transform(sp.scale(Coeff_train_n7))

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1,2,1)
ax.bar(range(10), acp3.explained_variance_ratio_[:10]*100, align='center',
        color='grey', ecolor='black')
ax.set_xticks(range(10))
ax.set_ylabel("Variance")
ax.set_title("Pourcentage de variance expliqué \n des premières composantes", fontsize=20)

ax = fig.add_subplot(1,2,2)
box=ax.boxplot(X_acp3[:,0:10])
ax.set_title("Distribution des premières composante", fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1079.8166334129219">

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1,2,1)
labels=[]
for x,y,s, a in zip(X_acp3[:,0], X_acp3[:,1], map(str,range(240)), Y_train_label):
    ax.plot(x,y,marker=".", color=COLOR_DIC[a])
    if a!=0:
        label = ACTIVITY_DIC[a]
        ax.text(x,y,s, horizontalalignment="center", verticalalignment="center", color=COLOR_DIC[a])
        if not(label in labels):
            labels.append(label)
            ax.plot(x,y,marker=".", color=COLOR_DIC[a], label = label, linestyle="None")
plt.legend(fontsize=15)
ax.set_title("Projection des invididus sur les \n  deux premières composantes", fontsize=20)


ax = fig.add_subplot(1,2,2)
for x,y,s in zip(acp3.components_[0], acp3.components_[1], map(str,range(256))):
    ax.text(x,y,s, horizontalalignment="center", verticalalignment="center", color="red")
ax.set_xlim(acp3.components_[0].min()-0.002,acp3.components_[0].max()+0.002)
ax.set_ylim(acp3.components_[1].min()-0.01,acp3.components_[1].max()+0.01)
ax.set_title("Projection des features sur les \n  deux premières composantes", fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1079.8166334129219">

# %% [markdown]
# #### b. coefficients des niveaux J=0 à  6

# %%
acp4 = sd.PCA()
X_acp4 = acp4.fit_transform(sp.scale(Coeff_train_n1_6))

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1,2,1)
ax.bar(range(10), acp4.explained_variance_ratio_[:10]*100, align='center',
        color='grey', ecolor='black')
ax.set_xticks(range(10))
ax.set_ylabel("Variance")
ax.set_title("Pourcentage de variance expliqué \n des premières composantes", fontsize=20)

ax = fig.add_subplot(1,2,2)
box=ax.boxplot(X_acp4[:,0:10])
ax.set_title("Distribution des premières composante", fontsize=20)
ax.set_title("Projection des features sur les \n  deux premières composantes", fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1079.8166334129219">

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1,2,1)
labels=[]
for x,y,s, a in zip(X_acp4[:,0], X_acp4[:,1], map(str,range(240)), Y_train_label):
    ax.plot(x,y,marker=".", color=COLOR_DIC[a])
    if a!=0:
        label = ACTIVITY_DIC[a]
        ax.text(x,y,s, horizontalalignment="center", verticalalignment="center", color=COLOR_DIC[a])
        if not(label in labels):
            labels.append(label)
            ax.plot(x,y,marker=".", color=COLOR_DIC[a], label = label, linestyle="None")
ax.set_title("Projection des invididus sur les \n  deux premières composantes", fontsize=20)

plt.legend(fontsize=15)

ax = fig.add_subplot(1,2,2)
for x,y,s in zip(acp4.components_[0], acp4.components_[1], map(str,range(256))):
    ax.text(x,y,s, horizontalalignment="center", verticalalignment="center", color="red")
ax.set_xlim(acp4.components_[0].min()-0.002,acp4.components_[0].max()+0.002)
ax.set_ylim(acp4.components_[1].min()-0.01,acp4.components_[1].max()+0.01)
ax.set_title("Projection des features sur les \n  deux premières composantes", fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1079.8166334129219">

# %% [markdown]
# #### c. Coefficients seuillés

# %%
acp5 = sd.PCA()
X_acp5 = acp5.fit_transform(sp.scale(TCoeff))

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1,2,1)
ax.bar(range(10), acp5.explained_variance_ratio_[:10]*100, align='center',
        color='grey', ecolor='black')
ax.set_xticks(range(10))
ax.set_ylabel("Variance")
ax.set_title("Pourcentage de variance expliqué \n des premières composantes", fontsize=20)

ax = fig.add_subplot(1,2,2)
box=ax.boxplot(X_acp5[:,0:10])
ax.set_title("Distribution des premières composante", fontsize=20)
ax.set_title("Projection des features sur les \n  deux premières composantes", fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1079.8166334129219">

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1,2,1)
labels=[]
for x,y,s, a in zip(X_acp5[:,0], X_acp5[:,1], map(str,range(240)), Y_train_label):
    ax.plot(x,y,marker=".", color=COLOR_DIC[a])
    if a!=0:
        label = ACTIVITY_DIC[a]
        ax.text(x,y,s, horizontalalignment="center", verticalalignment="center", color=COLOR_DIC[a])
        if not(label in labels):
            labels.append(label)
            ax.plot(x,y,marker=".", color=COLOR_DIC[a], label = label, linestyle="None")
ax.set_title("Projection des invididus sur les \n  deux premières composantes", fontsize=20)

plt.legend(fontsize=15)

ax = fig.add_subplot(1,2,2)
for x,y,s in zip(acp5.components_[0], acp5.components_[1], map(str,range(256))):
    ax.text(x,y,s, horizontalalignment="center", verticalalignment="center", color="red")
ax.set_xlim(acp5.components_[0].min()-0.002,acp5.components_[0].max()+0.002)
ax.set_ylim(acp5.components_[1].min()-0.01,acp5.components_[1].max()+0.01)
ax.set_title("Projection des features sur les \n  deux premières composantes", fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1079.8166334129219">

# %% [markdown]
# ## 3 Apprentissage des signaux uni-dimensionels
#
# La base d'apprentissage est de dimension (`N_train`, 1152)

# %% [markdown]
# ### 3.1 Régression Logistique
#
# #### Principe
# Une méthode ancienne mais parmi celles conduisant aux meilleurs résultats sur les variables métier. La régression logistique est adaptée à la prévision d'une variable binaire. Dans le cas multiclasse, la fonction logistique de la librairie `Scikit-learn` estime par défaut un modèle par classe, cette classe contre les autres.
#
# La probabilité d'appartenance d'un individu à une classe est modélisée à l'aide d'une combinaison linéaire des variables explicatives. Pour transformer une combinaison linéaire à valeur dans $R$ en une probabilité à valeurs dans l'intervalle $[0, 1]$, une fonction de forme sigmoïdale, inverse de la fonction *logit*, est appliquée.  Ceci donne: $P(y_i=1)=\frac{e^{Xb}}{1+e^{Xb}}$ ou encore, $\log\frac{P(y_i=1)}{1-P(y_i=1)}=Xb$
#
#
# #### a. Sur données brutes

# %%
t_start = time.time()
model_lr = lm.LogisticRegression(verbose=1)
model_lr.fit(X_train_flatten, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lr.score(X_test_flatten, Y_test_label)
print("Score With Logistic Regression on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lr_prediction_label = model_lr.predict(X_test_flatten)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lr_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# [LibLinear]Score With Logistic Regression on Inertial Signals = 57.45, Learning time = 32.91 secondes
#      1    2    3    4    5    6
# 1  120   63   97    0    1    0
# 2   74  218   56   23   72   27
# 3   92   66  103    1    2    0
# 4   79   32   58  397  112    0
# 5  131   92  106   70  345    0
# 6    0    0    0    0    0  510

# %% [markdown]
# #### b. Sur tous les coefficients d'ondelettes

# %%
t_start = time.time()
model_lr = lm.LogisticRegression(verbose=1)
model_lr.fit(Coeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lr.score(Coeff_test, Y_test_label)
print("Score With Logistic Regression on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lr_prediction_label = model_lr.predict(Coeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lr_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# [LibLinear]Score With Logistic Regression on Inertial Signals = 57.45, Learning time = 34.23 secondes
#      1    2    3    4    5    6
# 1  120   63   97    0    1    0
# 2   74  218   56   23   72   27
# 3   92   66  103    1    2    0
# 4   79   32   58  397  112    0
# 5  131   92  106   70  345    0
# 6    0    0    0    0    0  510

# %% [markdown]
# #### c. Sur coefficients d'ondelettes de niveau 7

# %%
t_start = time.time()
model_lr = lm.LogisticRegression(verbose=1)
model_lr.fit(Coeff_train_n7, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lr.score(Coeff_test_n7, Y_test_label)
print("Score With Logistic Regression on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lr_prediction_label = model_lr.predict(Coeff_test_n7)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lr_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# [LibLinear]Score With Logistic Regression on Inertial Signals = 29.96, Learning time = 5.01 secondes
#      1    2    3    4    5    6
# 1  140  114  115    2    2    0
# 2   69   94   77    0    2    1
# 3  117   77   95    0    0    0
# 4   11    6    1    0    0    0
# 5   69   70   53   23   28   10
# 6   90  110   79  466  500  526

# %% [markdown]
# #### d. Sur coefficients d'ondelettes de niveau 1 à 6

# %%
t_start = time.time()
model_lr = lm.LogisticRegression(verbose=1)
model_lr.fit(Coeff_train_n1_6, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lr.score(Coeff_test_n1_6, Y_test_label)
print("Score With Logistic Regression on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lr_prediction_label = model_lr.predict(Coeff_test_n1_6)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lr_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# [LibLinear]Score With Logistic Regression on Inertial Signals = 58.03, Learning time = 18.34 secondes
#      1    2    3    4    5    6
# 1  120   63   85    0    6    0
# 2   91  230   59   23   72   27
# 3   75   63  113    1    2    0
# 4   76   33   61  396  111    0
# 5  134   82  102   71  341    0
# 6    0    0    0    0    0  510

# %% [markdown]
# #### e. Sur coefficients d'ondelettes seuillés

# %%
t_start = time.time()
model_lr = lm.LogisticRegression(verbose=1)
model_lr.fit(TCoeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lr.score(TCoeff_test, Y_test_label)
print("Score With Logistic Regression on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lr_prediction_label = model_lr.predict(TCoeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lr_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# [LibLinear]Score With Logistic Regression on Inertial Signals = 65.12, Learning time = 11.09 secondes
#      1    2    3    4    5    6
# 1  257   97   82    0    0    0
# 2   76  256   30   23   44   27
# 3   41   18  128    1    2    0
# 4   47   33   35  391  109    0
# 5   75   67  145   76  377    0
# 6    0    0    0    0    0  510

# %% [markdown]
# #### f. Optimisation

# %%
# Optimisation du paramètre de pénalisation
# grille de valeurs
ts = time.time()
param=[{"C":[0.5, 1, 2, 4],"penalty":["l1","l2"]}]
logit = GridSearchCV(lm.LogisticRegression(verbose=1), param,cv=10,n_jobs=-1)
logitOpt=logit.fit(X_train_flatten, Y_train_label)
te = time.time()
print("Temps : %d secondes" %(te-ts))
print("Meilleur score = %f, Meilleur paramètre = %s" % (logitOpt.best_score_,logitOpt.best_params_))
yChap = logitOpt.predict(X_test_flatten)
# matrice de confusion
logitOpt.score(X_test_flatten, Y_test_label)
pd.DataFrame(confusion_matrix(yChap, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Temps : 3246 secondes
# Meilleur score = 0.609902, Meilleur paramètre = {'C': 4, 'penalty': 'l2'}
#      1    2    3    4    5    6
# 1  116   66  102    0    2    0
# 2   72  210   55   24   71   27
# 3   90   73  102    1    3    0
# 4   75   34   53  382  109    0
# 5  143   88  108   84  347    0
# 6    0    0    0    0    0  510

# %% [markdown]
# **Q** Que dire de la performance?
#
# **TODO?** Tester d'autre méthode (SVM, XGBOOST?)

# %% [markdown]
# ### 3.2 [Analyse discriminante linéaire](http://wikistat.fr/pdf/st-m-app-add.pdf)
# #### Principe
# Cette méthode, également ancienne, est principalement due à Fisher dans les années trente. La règle d'affectation d'un nouvel individu à une classe est basée sur la *distance de Mahalanobis*. Cette distance est définie par la matrice inverse de la matrice de covariance intra-classe. Un individu est affecté à la classe dont le barycentre est le plus proche au sens de cette métrique. L'inversion de la matrice pose des problèmes si les variables explicatives sont colinéaires ou presque. L'algorithme utilisé par défaut dans `Scikit-learn` (SVD) le contourne et fournit un avertissement mais des résultats.
#
# Implicitement, cette méthode suppose que les variables sont gaussiennes multidimensionnelles ainsi qu'une hypothèse d'homoscédasticité: les classes partagent la même structure (matrice) de covariance. Sans hypothèse d'homoscédasticité, une matrice de covariance devrait être estimée pour chaque classe. Il s'agit alors d'une analyse discriminante quadratique. Les problèmes de multicolinéarité empêchent l'utilisation de cette approche. il faudrait procéder à une sélection préalable des données ou éventuellement la calculer sut les premières composantes principales de l'ACP afin d'éviter les probèmes de conditionnement des matrices.

# %%
t_start = time.time()
model_lda = sda.LinearDiscriminantAnalysis()
model_lda.fit(X_train_flatten, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lda.score(X_test_flatten, Y_test_label)
print("Score With Logistic Regression on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lda_prediction_label = model_lda.predict(X_test_flatten)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lda_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# Score With Logistic Regression on Inertial Signals = 58.84, Learning time = 9.58 secondes
#      1    2    3    4    5    6
# 1  132   93  114    0    4    0
# 2   74  146   58   23    6    0
# 3  117   69  113    2    3    0
# 4   15   23   18  313   26    0
# 5  158  140  117  153  493    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### b. Sur tous les coefficients d'ondelettes

# %%
t_start = time.time()
model_lda = sda.LinearDiscriminantAnalysis()
model_lda.fit(Coeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lda.score(Coeff_test, Y_test_label)
print("Score With Logistic Regression on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lda_prediction_label = model_lda.predict(Coeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lda_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With Logistic Regression on Inertial Signals = 58.70, Learning time = 2.50 secondes
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
#      1    2    3    4    5    6
# 1  129   93  113    0    4    0
# 2   75  148   52   23    6    0
# 3  116   73  112    2    3    0
# 4   13   23   20  311   26    0
# 5  163  134  123  155  493    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### c. Sur coefficients d'ondelettes de niveau 7

# %%
t_start = time.time()
model_lda = sda.LinearDiscriminantAnalysis()
model_lda.fit(Coeff_train_n7, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lda.score(Coeff_test_n7, Y_test_label)
print("Score With Logistic Regression on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lda_prediction_label = model_lda.predict(Coeff_test_n7)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lda_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With Logistic Regression on Inertial Signals = 34.00, Learning time = 0.61 secondes
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
#      1    2    3    4    5    6
# 1  150   74   99    2    3    0
# 2   85  125   61    8    3    5
# 3  103   74  110    2    4    0
# 4   38   31   28   54   55   25
# 5   59   59   67  359  387  331
# 6   61  108   55   66   80  176

# %% [markdown]
# #### d. Sur coefficients d'ondelettes de niveau 1 à 6

# %%
t_start = time.time()
model_lda = sda.LinearDiscriminantAnalysis()
model_lda.fit(Coeff_train_n1_6, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lda.score(Coeff_test_n1_6, Y_test_label)
print("Score With Logistic Regression on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lda_prediction_label = model_lda.predict(Coeff_test_n1_6)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lda_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With Logistic Regression on Inertial Signals = 60.50, Learning time = 0.58 secondes
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
#      1    2    3    4    5    6
# 1  146   90   94    2    5    0
# 2   53  163   61   23   11    0
# 3  103   79  141    3    5    0
# 4   15   23   18  310   25    0
# 5  179  116  106  153  486    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### e. Sur coefficients d'ondelettes seuillés

# %%
t_start = time.time()
model_lda = sda.LinearDiscriminantAnalysis()
model_lda.fit(TCoeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lda.score(TCoeff_test, Y_test_label)
print("Score With Logistic Regression on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lda_prediction_label = model_lda.predict(TCoeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lda_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With Logistic Regression on Inertial Signals = 66.00, Learning time = 2.16 secondes
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
#      1    2    3    4    5    6
# 1  233   92   65    1    0    0
# 2   82  221   47    3    3    0
# 3   36   26  153    4    4    1
# 4   21   15   24  307   30    0
# 5  124  117  131  176  495    0
# 6    0    0    0    0    0  536

# %% [markdown]
# #### Analyse Discriminante Quadratique
# #### f. Sur données brutes

# %%
t_start = time.time()
model_qda = sda.QuadraticDiscriminantAnalysis()
model_qda.fit(X_train_flatten, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_qda.score(X_test_flatten, Y_test_label)
print("Score With Quadratic Discriminant Analysis on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
qda_prediction_label = model_qda.predict(X_test_flatten)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lda_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Score With Quadratic Discriminant Analysis on Inertial Signals = 44.32, Learning time = 5.56 secondes
#      1    2    3    4    5    6
# 1  233   92   65    1    0    0
# 2   82  221   47    3    3    0
# 3   36   26  153    4    4    1
# 4   21   15   24  307   30    0
# 5  124  117  131  176  495    0
# 6    0    0    0    0    0  536

# %% [markdown]
# #### g. Sur tous les coefficients d'ondelettes

# %%
t_start = time.time()
model_lda = sda.QuadraticDiscriminantAnalysis()
model_lda.fit(Coeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lda.score(Coeff_test, Y_test_label)
print("Score With Quadratic Discriminant Analysis on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lda_prediction_label = model_lda.predict(Coeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lda_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Score With Quadratic Discriminant Analysis on Inertial Signals = 44.04, Learning time = 6.09 secondes
#      1    2    3    4    5    6
# 1  496  471  420  128  217   20
# 2    0    0    0    0    0    0
# 3    0    0    0    0    0    0
# 4    0    0    0    3    0    0
# 5    0    0    0  202  282    0
# 6    0    0    0  158   33  517

# %% [markdown]
# #### h. Sur coefficients d'ondelettes de niveau 7

# %%
t_start = time.time()
model_lda = sda.QuadraticDiscriminantAnalysis()
model_lda.fit(Coeff_train_n7, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lda.score(Coeff_test_n7, Y_test_label)
print("Score With Quadratic Discriminant Analysis on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lda_prediction_label = model_lda.predict(Coeff_test_n7)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lda_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Score With Quadratic Discriminant Analysis on Inertial Signals = 71.67, Learning time = 1.35 secondes
#      1    2    3    4    5    6
# 1  420   24    0    0    0    0
# 2    0  340    0   70  119   64
# 3   76  107  420    0    0    9
# 4    0    0    0  171   34   33
# 5    0    0    0  159  347   17
# 6    0    0    0   91   32  414

# %% [markdown]
# #### i. Sur coefficients d'ondelettes de niveau 1 à 6

# %%
t_start = time.time()
model_lda = sda.QuadraticDiscriminantAnalysis()
model_lda.fit(Coeff_train_n1_6, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lda.score(Coeff_test_n1_6, Y_test_label)
print("Score With Quadratic Discriminant Analysis on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lda_prediction_label = model_lda.predict(Coeff_test_n1_6)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lda_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Score With Quadratic Discriminant Analysis on Inertial Signals = 58.47, Learning time = 0.81 secondes
#      1    2    3    4    5    6
# 1  473   33  116    4    0   24
# 2    2  428  133   68  167   17
# 3   21   10  171    1    0    0
# 4    0    0    0  377  228  359
# 5    0    0    0   38  137    0
# 6    0    0    0    3    0  137

# %% [markdown]
# #### j. Sur coefficients d'ondelettes seuillés

# %%
t_start = time.time()
model_lda = sda.QuadraticDiscriminantAnalysis()
model_lda.fit(TCoeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_lda.score(TCoeff_test, Y_test_label)
print("Score With Quadratic Discriminant Analysis on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
lda_prediction_label = model_lda.predict(TCoeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(lda_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Score With Quadratic Discriminant Analysis on Inertial Signals = 41.30, Learning time = 4.34 secondes
#      1    2    3    4    5    6
# 1  480  442  397  119  215   37
# 2    0    0    0    0    0    0
# 3    0    0    0    0    0    0
# 4    0    1    1    7   12    6
# 5    2    2    3  213  244    8
# 6   14   26   19  152   61  486

# %% [markdown]
# Les performances de l'analyse discriminante quadratique avec les paramètres par défault ne semblent pas justifier une optimisation de ces derniers.

# %% [markdown]
# ### 3.3 Perceptron multicouche
#
# Un réseau de neurones classique est appris sur les données au même format que précédemment.
#
# **Q** Expliciter les choix des paramètres et donc la structure du réseau.

# %%
epochs = 10
batch_size = 32
n_hidden = 32

n_features = X_train_flatten.shape[1]
n_classes=6

model_base_mlp_u =km.Sequential()
model_base_mlp_u.add(kl.Dense(n_hidden, input_shape=(n_features,),  activation = "relu"))
model_base_mlp_u.add(kl.Dropout(0.5))
model_base_mlp_u.add(kl.Dense(n_classes, activation='softmax'))
model_base_mlp_u.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model_base_mlp_u.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 32)                36896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 198
# ...
# Total params: 37,094
# Trainable params: 37,094
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### a. Sur données brutes

# %%
t_start = time.time()
model_base_mlp_u.fit(X_train_flatten,  Y_train_dummies, batch_size=batch_size, validation_data=(X_test_flatten, Y_test_dummies), epochs=epochs)
t_end = time.time()
t_learning = t_end-t_start

score = model_base_mlp_u.evaluate(X_test_flatten, Y_test_dummies)[1] 
print("\nScore With Simple MLP on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
metadata_mlp_u = {"time_learning" : t_learning, "score" : score}
base_mlp_u_prediction = model_base_mlp_u.predict(X_test_flatten)

my_confusion_matrix(Y_test_dummies, base_mlp_u_prediction)
# Out:
# Train on 7352 samples, validate on 2947 samples
# Epoch 1/10
# 7352/7352 [==============================] - 0s - loss: 1.1588 - acc: 0.5340 - val_loss: 0.9268 - val_acc: 0.7536
# Epoch 2/10
# 7352/7352 [==============================] - 0s - loss: 0.8472 - acc: 0.6949 - val_loss: 0.7479 - val_acc: 0.7927
# Epoch 3/10
# 7352/7352 [==============================] - 0s - loss: 0.7196 - acc: 0.7515 - val_loss: 0.6235 - val_acc: 0.8358
# Epoch 4/10
# 7352/7352 [==============================] - 0s - loss: 0.6363 - acc: 0.7711 - val_loss: 0.5950 - val_acc: 0.8337
# Epoch 5/10
# 7352/7352 [==============================] - 0s - loss: 0.5955 - acc: 0.7882 - val_loss: 0.5754 - val_acc: 0.8449
# Epoch 6/10
# 7352/7352 [==============================] - 0s - loss: 0.5692 - acc: 0.7920 - val_loss: 0.5479 - val_acc: 0.8453
# Epoch 7/10
# 7352/7352 [==============================] - 0s - loss: 0.5425 - acc: 0.8032 - val_loss: 0.5252 - val_acc: 0.8341
# Epoch 8/10
# ...

# %% [markdown]
# #### b. Sur tous les coefficients d'ondelettes

# %%
epochs = 10
batch_size = 32
n_hidden = 32

n_features = Coeff_train.shape[1]
n_classes=6

model_base_mlp_u =km.Sequential()
model_base_mlp_u.add(kl.Dense(n_hidden, input_shape=(n_features,),  activation = "relu"))
model_base_mlp_u.add(kl.Dropout(0.5))
model_base_mlp_u.add(kl.Dense(n_classes, activation='softmax'))
model_base_mlp_u.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model_base_mlp_u.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 32)                36928
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 198
# ...
# Total params: 37,126
# Trainable params: 37,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
t_start = time.time()
model_base_mlp_u.fit(Coeff_train,  Y_train_dummies, batch_size=batch_size, validation_data=(Coeff_test, Y_test_dummies), epochs=epochs)
t_end = time.time()
t_learning = t_end-t_start

score = model_base_mlp_u.evaluate(Coeff_test, Y_test_dummies)[1] 
print("\nScore With Simple MLP on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
metadata_mlp_u = {"time_learning" : t_learning, "score" : score}
base_mlp_u_prediction = model_base_mlp_u.predict(Coeff_test)

my_confusion_matrix(Y_test_dummies, base_mlp_u_prediction)
# Out:
# Train on 7352 samples, validate on 2947 samples
# Epoch 1/10
# 7352/7352 [==============================] - 0s - loss: 1.2968 - acc: 0.4901 - val_loss: 0.9552 - val_acc: 0.6980
# Epoch 2/10
# 7352/7352 [==============================] - 0s - loss: 0.8904 - acc: 0.6604 - val_loss: 0.7110 - val_acc: 0.7913
# Epoch 3/10
# 7352/7352 [==============================] - 0s - loss: 0.7349 - acc: 0.7242 - val_loss: 0.6044 - val_acc: 0.8307
# Epoch 4/10
# 7352/7352 [==============================] - 0s - loss: 0.6517 - acc: 0.7545 - val_loss: 0.5392 - val_acc: 0.8402
# Epoch 5/10
# 7352/7352 [==============================] - 0s - loss: 0.5829 - acc: 0.7791 - val_loss: 0.4888 - val_acc: 0.8504
# Epoch 6/10
# 7352/7352 [==============================] - 0s - loss: 0.5577 - acc: 0.7881 - val_loss: 0.4674 - val_acc: 0.8575
# Epoch 7/10
# 7352/7352 [==============================] - 0s - loss: 0.5339 - acc: 0.8006 - val_loss: 0.4539 - val_acc: 0.8602
# Epoch 8/10
# ...

# %% [markdown]
# #### c. Sur coefficients d'ondelettes de niveau 7

# %%
epochs = 10
batch_size = 32
n_hidden = 32

n_features = Coeff_train_n7.shape[1]
n_classes=6

model_base_mlp_u =km.Sequential()
model_base_mlp_u.add(kl.Dense(n_hidden, input_shape=(n_features,),  activation = "relu"))
model_base_mlp_u.add(kl.Dropout(0.5))
model_base_mlp_u.add(kl.Dense(n_classes, activation='softmax'))
model_base_mlp_u.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model_base_mlp_u.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7 (Dense)              (None, 32)                18496
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 6)                 198
# ...
# Total params: 18,694
# Trainable params: 18,694
# Non-trainable params: 0
# _________________________________________________________________

# %%
t_start = time.time()
model_base_mlp_u.fit(Coeff_train_n7,  Y_train_dummies, batch_size=batch_size, validation_data=(Coeff_test_n7, Y_test_dummies), epochs=epochs)
t_end = time.time()
t_learning = t_end-t_start

score = model_base_mlp_u.evaluate(Coeff_test_n7, Y_test_dummies)[1] 
print("\nScore With Simple MLP on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
metadata_mlp_u = {"time_learning" : t_learning, "score" : score}
base_mlp_u_prediction = model_base_mlp_u.predict(Coeff_test_n7)

my_confusion_matrix(Y_test_dummies, base_mlp_u_prediction)
# Out:
# Train on 7352 samples, validate on 2947 samples
# Epoch 1/10
# 7352/7352 [==============================] - 0s - loss: 1.7154 - acc: 0.3093 - val_loss: 1.6473 - val_acc: 0.3549
# Epoch 2/10
# 7352/7352 [==============================] - 0s - loss: 1.5559 - acc: 0.3547 - val_loss: 1.5032 - val_acc: 0.3560
# Epoch 3/10
# 7352/7352 [==============================] - 0s - loss: 1.4175 - acc: 0.3721 - val_loss: 1.3774 - val_acc: 0.3729
# Epoch 4/10
# 7352/7352 [==============================] - 0s - loss: 1.3080 - acc: 0.3874 - val_loss: 1.2866 - val_acc: 0.3946
# Epoch 5/10
# 7352/7352 [==============================] - 0s - loss: 1.2469 - acc: 0.3920 - val_loss: 1.2249 - val_acc: 0.4143
# Epoch 6/10
# 7352/7352 [==============================] - 0s - loss: 1.1874 - acc: 0.4117 - val_loss: 1.1806 - val_acc: 0.4245
# Epoch 7/10
# 7352/7352 [==============================] - 0s - loss: 1.1590 - acc: 0.4157 - val_loss: 1.1500 - val_acc: 0.4313
# Epoch 8/10
# ...

# %% [markdown]
# #### d. Sur coefficients d'ondelettes de niveau 1 à 6

# %%
epochs = 10
batch_size = 32
n_hidden = 32

n_features = Coeff_train_n1_6.shape[1]
n_classes=6

model_base_mlp_u =km.Sequential()
model_base_mlp_u.add(kl.Dense(n_hidden, input_shape=(n_features,),  activation = "relu"))
model_base_mlp_u.add(kl.Dropout(0.5))
model_base_mlp_u.add(kl.Dense(n_classes, activation='softmax'))
model_base_mlp_u.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model_base_mlp_u.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_9 (Dense)              (None, 32)                18464
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 198
# ...
# Total params: 18,662
# Trainable params: 18,662
# Non-trainable params: 0
# _________________________________________________________________

# %%
t_start = time.time()
model_base_mlp_u.fit(Coeff_train_n1_6,  Y_train_dummies, batch_size=batch_size, validation_data=(Coeff_test_n1_6, Y_test_dummies), epochs=epochs)
t_end = time.time()
t_learning = t_end-t_start

score = model_base_mlp_u.evaluate(Coeff_test_n1_6, Y_test_dummies)[1] 
print("\nScore With Simple MLP on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
metadata_mlp_u = {"time_learning" : t_learning, "score" : score}
base_mlp_u_prediction = model_base_mlp_u.predict(Coeff_test_n1_6)

my_confusion_matrix(Y_test_dummies, base_mlp_u_prediction)
# Out:
# Train on 7352 samples, validate on 2947 samples
# Epoch 1/10
# 7352/7352 [==============================] - 0s - loss: 1.3355 - acc: 0.4723 - val_loss: 0.9902 - val_acc: 0.6960
# Epoch 2/10
# 7352/7352 [==============================] - 0s - loss: 0.9211 - acc: 0.6681 - val_loss: 0.7491 - val_acc: 0.7791
# Epoch 3/10
# 7352/7352 [==============================] - 0s - loss: 0.7742 - acc: 0.7210 - val_loss: 0.6382 - val_acc: 0.8246
# Epoch 4/10
# 7352/7352 [==============================] - 0s - loss: 0.6919 - acc: 0.7488 - val_loss: 0.5695 - val_acc: 0.8334
# Epoch 5/10
# 7352/7352 [==============================] - 0s - loss: 0.6125 - acc: 0.7760 - val_loss: 0.5270 - val_acc: 0.8459
# Epoch 6/10
# 7352/7352 [==============================] - 0s - loss: 0.5763 - acc: 0.7912 - val_loss: 0.5003 - val_acc: 0.8558
# Epoch 7/10
# 7352/7352 [==============================] - 0s - loss: 0.5549 - acc: 0.7973 - val_loss: 0.4866 - val_acc: 0.8636
# Epoch 8/10
# ...

# %% [markdown]
# #### e. Sur coefficients d'ondelettes seuillés

# %%
epochs = 10
batch_size = 32
n_hidden = 32

n_features = TCoeff_train.shape[1]
n_classes=6

model_base_mlp_u =km.Sequential()
model_base_mlp_u.add(kl.Dense(n_hidden, input_shape=(n_features,),  activation = "relu"))
model_base_mlp_u.add(kl.Dropout(0.5))
model_base_mlp_u.add(kl.Dense(n_classes, activation='softmax'))
model_base_mlp_u.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model_base_mlp_u.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_11 (Dense)             (None, 32)                36928
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 6)                 198
# ...
# Total params: 37,126
# Trainable params: 37,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
t_start = time.time()
model_base_mlp_u.fit(Coeff_train,  Y_train_dummies, batch_size=batch_size, validation_data=(Coeff_test, Y_test_dummies), epochs=epochs)
t_end = time.time()
t_learning = t_end-t_start

score = model_base_mlp_u.evaluate(Coeff_test, Y_test_dummies)[1] 
print("\nScore With Simple MLP on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
metadata_mlp_u = {"time_learning" : t_learning, "score" : score}
base_mlp_u_prediction = model_base_mlp_u.predict(Coeff_test)

my_confusion_matrix(Y_test_dummies, base_mlp_u_prediction)
# Out:
# Train on 7352 samples, validate on 2947 samples
# Epoch 1/10
# 7352/7352 [==============================] - 0s - loss: 1.3272 - acc: 0.4988 - val_loss: 0.9456 - val_acc: 0.7343
# Epoch 2/10
# 7352/7352 [==============================] - 0s - loss: 0.8707 - acc: 0.6982 - val_loss: 0.6847 - val_acc: 0.8076
# Epoch 3/10
# 7352/7352 [==============================] - 0s - loss: 0.6877 - acc: 0.7514 - val_loss: 0.5729 - val_acc: 0.8334
# Epoch 4/10
# 7352/7352 [==============================] - 0s - loss: 0.5986 - acc: 0.7885 - val_loss: 0.5151 - val_acc: 0.8473
# Epoch 5/10
# 7352/7352 [==============================] - 0s - loss: 0.5550 - acc: 0.8040 - val_loss: 0.4808 - val_acc: 0.8480
# Epoch 6/10
# 7352/7352 [==============================] - 0s - loss: 0.5295 - acc: 0.8070 - val_loss: 0.4697 - val_acc: 0.8473
# Epoch 7/10
# 7352/7352 [==============================] - 0s - loss: 0.4987 - acc: 0.8207 - val_loss: 0.4537 - val_acc: 0.8531
# Epoch 8/10
# ...

# %% [markdown]
# #### f. Optimisation

# %%
epochs = 11
batch_size = 32
n_hidden_1 = 50
n_hidden_2 = 50
#n_hidden_3 = 50

n_features = X_train_flatten.shape[1]
n_classes=6

model_base_mlp_u =km.Sequential()
# First Layer
model_base_mlp_u.add(kl.Dense(n_hidden_1, input_shape=(n_features,),  activation = "relu"))
model_base_mlp_u.add(kl.Dropout(0.3))
# Second Layer
model_base_mlp_u.add(kl.Dense(n_hidden_2, input_shape=(n_hidden_1,),  activation = "relu"))
model_base_mlp_u.add(kl.Dropout(0.3))
# Third Layer
#model_base_mlp_u.add(kl.Dense(n_hidden_3, input_shape=(n_hidden_2,),  activation = "relu"))
#model_base_mlp_u.add(kl.Dropout(0.5))

# Fourth
model_base_mlp_u.add(kl.Dense(n_classes, activation='softmax'))
model_base_mlp_u.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model_base_mlp_u.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_62 (Dense)             (None, 50)                57650
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_63 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_64 (Dense)             (None, 6)                 306
# ...
# Total params: 60,506
# Trainable params: 60,506
# Non-trainable params: 0
# _________________________________________________________________

# %%
t_start = time.time()
model_base_mlp_u.fit(X_train_flatten,  Y_train_dummies, batch_size=batch_size, validation_data=(X_test_flatten, Y_test_dummies), epochs=epochs)
t_end = time.time()
t_learning = t_end-t_start

score = model_base_mlp_u.evaluate(X_test_flatten, Y_test_dummies)[1] 
print("\nScore With Simple MLP on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
metadata_mlp_u = {"time_learning" : t_learning, "score" : score}
base_mlp_u_prediction = model_base_mlp_u.predict(X_test_flatten)

my_confusion_matrix(Y_test_dummies, base_mlp_u_prediction)
# Out:
# Train on 7352 samples, validate on 2947 samples
# Epoch 1/11
# 7352/7352 [==============================] - 1s - loss: 1.0259 - acc: 0.6026 - val_loss: 0.7057 - val_acc: 0.7950
# Epoch 2/11
# 7352/7352 [==============================] - 0s - loss: 0.5947 - acc: 0.7881 - val_loss: 0.5043 - val_acc: 0.8385
# Epoch 3/11
# 7352/7352 [==============================] - 0s - loss: 0.4637 - acc: 0.8375 - val_loss: 0.4971 - val_acc: 0.8473
# Epoch 4/11
# 7352/7352 [==============================] - 0s - loss: 0.3921 - acc: 0.8645 - val_loss: 0.4008 - val_acc: 0.8588
# Epoch 5/11
# 7352/7352 [==============================] - 0s - loss: 0.3463 - acc: 0.8798 - val_loss: 0.4114 - val_acc: 0.8605
# Epoch 6/11
# 7352/7352 [==============================] - 0s - loss: 0.3269 - acc: 0.8830 - val_loss: 0.3399 - val_acc: 0.8839
# Epoch 7/11
# 7352/7352 [==============================] - 0s - loss: 0.2985 - acc: 0.8938 - val_loss: 0.3570 - val_acc: 0.8850
# Epoch 8/11
# ...

# %% [markdown]
# ** Q ** : Que conclure sur ces résultats en terme de performance, de temps d'apprentissage? Comparer avec la regression logistique?
#
# ** Exo ** : Quel est l'influence de l'ajout de nouvelle couche? Supression du Dropout? ...

# %% [markdown]
# ### 3.4 SVM
#
# #### Principe
# La recherche de séparateurs à *vaste marge* est en principe adaptée à la discrimination de deux classes. Comme pour la régression logistique et par défaut, le cas multiclasse se traite en cherchant un hyperplan séparateur pour chaque classe contre les autres. Difficile de résumer en quelques lignes le principe de cet algoirhtme basé sur une optimisation quadratique de la *marge* d'un hyperplan séparateur sous contraintes que les individus soient bien situés de part et d'autre de l'hyperplan. L'astuce du noyau, souvent gaussien, permet de rendre linaire des problèmes qui ne le sont pas. Dans le cas présent, la version linéaire conduit à de bons résulats alors que l'utilisation du noyau gaussien ne les améliore pas, même après un effort d'optimisation des paramètres de pénalisation et de régularité du noyau.

# %% [markdown]
# #### SVM Linéaire

# %% [markdown]
# #### a. Sur données brutes

# %%
t_start = time.time()
model_svm = LinearSVC()
model_svm.fit(X_train_flatten, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_svm.score(X_test_flatten, Y_test_label)
print("Score With SVM Linéaire on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
svm_prediction_label = model_svm.predict(X_test_flatten)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(svm_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With Logistic Regression on Inertial Signals = 56.06, Learning time = 76.64 secondes
#      1    2    3    4    5    6
# 1  108   57   93    0    2    0
# 2   70  197   56   24   69   27
# 3   93   84  102    2    1    0
# 4   88   34   62  393  118    0
# 5  137   99  107   72  342    0
# 6    0    0    0    0    0  510

# %% [markdown]
# #### b. Sur tous les coefficients d'ondelettes

# %%
t_start = time.time()
model_svm = LinearSVC()
model_svm.fit(Coeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_svm.score(Coeff_test, Y_test_label)
print("Score With SVM Linéaire on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
svm_prediction_label = model_svm.predict(Coeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(svm_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With SVM Linéaire on Inertial Signals = 55.72, Learning time = 75.72 secondes
#      1    2    3    4    5    6
# 1  151  102  137    1   62    0
# 2   85  223   60   25   90   27
# 3   83   47   86    1    2    0
# 4   85   35   61  412  118    0
# 5   92   64   76   52  260    0
# 6    0    0    0    0    0  510

# %% [markdown]
# #### c. Sur les coefficients d'ondelettes de Niveau le plus fin

# %%
t_start = time.time()
model_svm = LinearSVC()
model_svm.fit(Coeff_train_n7, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_svm.score(Coeff_test_n7, Y_test_label)
print("Score With SVM Linéaire on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
svm_prediction_label = model_svm.predict(Coeff_test_n7)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(svm_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With SVM Linéaire on Inertial Signals = 33.02, Learning time = 59.22 secondes
#      1    2    3    4    5    6
# 1  145  118  111    3    3    0
# 2   80  112   77    1    5    2
# 3  135   99  115    0    7    1
# 4   14   10   15    5    2    0
# 5   47   60   42  104  111   49
# 6   75   72   60  378  404  485

# %% [markdown]
# #### d. Sur les coefficients d'ondelettes de 1 à 6

# %%
t_start = time.time()
model_svm = LinearSVC()
model_svm.fit(Coeff_train_n1_6, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_svm.score(Coeff_test_n1_6, Y_test_label)
print("Score With SVM Linéaire on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
svm_prediction_label = model_svm.predict(Coeff_test_n1_6)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(svm_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With SVM Linéaire on Inertial Signals = 57.24, Learning time = 38.14 secondes
#      1    2    3    4    5    6
# 1   92   42   71    0    0    0
# 2   71  217   49   25   67   27
# 3   92   77  133    1    7    0
# 4   80   37   60  387  110    0
# 5  161   98  107   78  348    0
# 6    0    0    0    0    0  510

# %% [markdown]
# #### e. Sur les coefficients d'ondelettes seuillés

# %%
t_start = time.time()
model_svm = LinearSVC()
model_svm.fit(TCoeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_svm.score(TCoeff_test, Y_test_label)
print("Score With SVM Linéaire on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
svm_prediction_label = model_svm.predict(TCoeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(svm_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With SVM Linéaire on Inertial Signals = 66.30, Learning time = 17.42 secondes
#      1    2    3    4    5    6
# 1  259   91   86    0    0    0
# 2   72  251   28   23   29   27
# 3   54   28  148    1    5    0
# 4   47   35   41  404  116    0
# 5   64   66  117   63  382    0
# 6    0    0    0    0    0  510

# %% [markdown]
# #### f. Optimisation
#
# Il est nécessaire d'optimiser le paramètre de pénalisation afin de limiter l'effet d'outliers ou de données faussées. En effet, s'il advenait qu'un individu de classe A a été maladroitement classé B lors de l'entrée des données, l'algorithme va fortement réagir à cette donnée éronnée si le paramètre de pénalisation est trop grand. En revanche, si les classes sont linéairement séparables, le paramètre de pénalisation n'aura aucune influence sur l'algorithme, celui-ci prendra uniquement en compte les points proche de la séparation linéaire pour optimiser la/les marge/s de séparation inter-classes.
#
# De façon générale, le paramètre de régularisation permet d'équilibrer l'ajustement du modèle pour éviter le sur-ajustement comme le sous-ajustement.

# %%
# Optimisation du paramètre de pénalisation
# grille de valeurs
ts = time.time()
#param=[{"C":[0.5,1,2,5]}]
#param=[{"C":[0.9,1,1.1]}]
#param=[{"C":[0.8,0.9,0.95]}]
param=[{"C":[0.7,0.8]}]
model = GridSearchCV(LinearSVC(verbose=1), param,cv=5,n_jobs=-1)
modelOpt=model.fit(X_train_flatten, Y_train_label)
te = time.time()
print("Temps : %d secondes" %(te-ts))
print("Meilleur score = %f, Meilleur paramètre = %s" % (modelOpt.best_score_,modelOpt.best_params_))
yChap = modelOpt.predict(X_test_flatten)
# matrice de confusion
modelOpt.score(X_test_flatten, Y_test_label)
pd.DataFrame(confusion_matrix(yChap, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# [LibLinear]Temps : 320 secondes
# Meilleur score = 0.606910, Meilleur paramètre = {'C': 0.7}
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
#      1    2    3    4    5    6
# 1  125   75  114    0   11    0
# 2   79  215   60   24   80   27
# 3   89   67   97    2    2    0
# 4   84   35   60  396  117    0
# 5  119   79   89   69  322    0
# 6    0    0    0    0    0  510

# %% [markdown]
# #### SVM avec noyau gaussien

# %% [markdown]
# #### a. Sur données brutes

# %%
t_start = time.time()
model_svm = SVC()
model_svm.fit(X_train_flatten, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_svm.score(X_test_flatten, Y_test_label)
print("Score With SVM on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
svm_prediction_label = model_svm.predict(X_test_flatten)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(svm_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With SVM on Inertial Signals = 76.96, Learning time = 43.24 secondes
#      1    2    3    4    5    6
# 1  407  152  150    1    2    0
# 2   34  261   50    6    0    0
# 3   39   58  217    0    0    0
# 4    0    0    0  371   55    0
# 5   16    0    3  113  475    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### b. Sur tous les coefficients d'ondelettes

# %%
t_start = time.time()
model_svm = SVC()
model_svm.fit(Coeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_svm.score(Coeff_test, Y_test_label)
print("Score With SVM on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
svm_prediction_label = model_svm.predict(Coeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(svm_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With SVM on Inertial Signals = 76.52, Learning time = 39.06 secondes
#      1    2    3    4    5    6
# 1  403  155  155    1    2    0
# 2   34  258   50   10    0    0
# 3   39   58  212    0    0    0
# 4    1    0    0  371   56    0
# 5   19    0    3  109  474    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### c. Sur les coefficients d'ondelettes de Niveau le plus fin

# %%
t_start = time.time()
model_svm = SVC()
model_svm.fit(Coeff_train_n7, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_svm.score(Coeff_test_n7, Y_test_label)
print("Score With SVM on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
svm_prediction_label = model_svm.predict(Coeff_test_n7)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(svm_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With SVM on Inertial Signals = 18.22, Learning time = 54.40 secondes
#      1    2    3    4    5    6
# 1    0    0    0    0    0    0
# 2    0    0    0    0    0    0
# 3    0    0    0    0    0    0
# 4    0    0    0    0    0    0
# 5    0    0    0    0    0    0
# 6  496  471  420  491  532  537

# %% [markdown]
# #### d. Sur les coefficients d'ondelettes de 1 à 6

# %%
t_start = time.time()
model_svm = SVC()
model_svm.fit(Coeff_train_n1_6, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_svm.score(Coeff_test_n1_6, Y_test_label)
print("Score With SVM on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
svm_prediction_label = model_svm.predict(Coeff_test_n1_6)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(svm_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With SVM on Inertial Signals = 82.22, Learning time = 11.14 secondes
#      1    2    3    4    5    6
# 1  449  100  107    1    0    0
# 2    6  317   33   23    3    0
# 3   35   54  280    0    0    0
# 4    2    0    0  374   63    0
# 5    4    0    0   93  466    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### e. Sur les coefficients d'ondelettes seuillés

# %%
t_start = time.time()
model_svm = SVC()
model_svm.fit(TCoeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_svm.score(TCoeff_test, Y_test_label)
print("Score With SVM on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
svm_prediction_label = model_svm.predict(TCoeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(svm_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With SVM Linéaire on Inertial Signals = 75.94, Learning time = 40.26 secondes
#      1    2    3    4    5    6
# 1  391  157  151    1    2    0
# 2   37  256   54   23    0    0
# 3   38   57  209    0    0    0
# 4    1    0    1  371   56    0
# 5   29    1    5   96  474    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### f. Optimisation
#
# Les paramètres optimisables sont:<br>
# * Le type de noyau utilisé (gaussien, polynomial, sigmoidal ou linéaire=LinearSVC)<br>
# * Le degré du polynôme dans le cas de noyau polynomial<br>
# * Le paramètre de pénalisation C<br>
# * Gamma, le coefficient du noyau
#
# En plus de ces paramètres, la librairie scikit-learn offre la possibilité d’utiliser un heuristique de seuillage ou de pondérer différemment les classes de la variable explicative ce qui peut potentiellement jouer sur le score final.

# %%
# Optimisation du paramètre de pénalisation
# grille de valeurs
ts = time.time()
param=[{"C":[0.5,0.9,1,1.1,2,5],"gamma":[.01,.02,.03]}]
model = GridSearchCV(SVC(verbose=1), param,cv=5,n_jobs=-1)
modelOpt=model.fit(X_train_flatten, Y_train_label)
te = time.time()
print("Temps : %d secondes" %(te-ts))
print("Meilleur score = %f, Meilleur paramètre = %s" % (modelOpt.best_score_,modelOpt.best_params_))
yChap = modelOpt.predict(X_test_flatten)
# matrice de confusion
modelOpt.score(X_test_flatten, Y_test_label)
pd.DataFrame(confusion_matrix(yChap, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# [LibSVM]Temps : 2012 secondes
# Meilleur score = 0.899755, Meilleur paramètre = {'C': 5, 'gamma': 0.01}
#      1    2    3    4    5    6
# 1  467   10   25    0    4    0
# 2    3  420   10   24    5   19
# 3   26   41  385    0    0    0
# 4    0    0    0  380   67    0
# 5    0    0    0   87  456    0
# 6    0    0    0    0    0  518

# %% [markdown]
# ### 3.5 RandomForest
#
# Algorithme beaucoup plus sophistiqué principalement dû à Léo Breiman (2001); il est basé sur l'agrégation d'arbres binaires de décision, régression ou classification, selon le type de la variable cible $y$. L'algorithme consiste à tirer `n_estimators` échantillons bootstrap. Comme dans le *bagging*, un arbre est estimé pour chaque échantillon bootstrap et la prévision est obtenue par moyene (régression) ou vote (classification) des prévisions individuelles de chaque arbre. Pour construire les arbres moins corrélés et rendre l'agrégation plus efficace, Breiman à ajouté au *bagging* une perturbation aléatoire. Lors de la construction de chaque noeud de chaque arbre, la division optimale est recherchée sur un sous-ensemble aléatoire des variables, de cardinal `max_valeur`.
#
# Cette méthode, très efficace pour résoudre des problèmes non linéaires apparaît moins performante lorsque les frontières des classes semblent assez linéaires. Son investigation (optimisation de `max_valeur`) ainsi que l'utilisation des algorithmes de principe similaire (*boosting*) ne sont pas approfondies.

# %% [markdown]
# #### a. Sur données brutes

# %%
t_start = time.time()
model_rf = RandomForestClassifier(n_estimators=200,n_jobs=-1)
model_rf.fit(X_train_flatten, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_rf.score(X_test_flatten, Y_test_label)
print("Score With RandomForest on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
rf_prediction_label = model_rf.predict(X_test_flatten)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(rf_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With RandomForest on Inertial Signals = 84.66, Learning time = 5.52 secondes
#      1    2    3    4    5    6
# 1  430   62   30    2    3    0
# 2   21  379   24   24    3    0
# 3   45   30  366    0    0    0
# 4    0    0    0  382  125    0
# 5    0    0    0   83  401    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### b. Sur tous les coefficients d'ondelettes

# %%
t_start = time.time()
model_rf = RandomForestClassifier(n_estimators=200, n_jobs=-1)
model_rf.fit(Coeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_rf.score(Coeff_test, Y_test_label)
print("Score With RandomForest on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
rf_prediction_label = model_rf.predict(Coeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(rf_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With RandomForest on Inertial Signals = 92.43, Learning time = 8.25 secondes
#      1    2    3    4    5    6
# 1  490   13   23    0    1    0
# 2    6  448   16    2    1    0
# 3    0   10  381    0    0    0
# 4    0    0    0  366   14    4
# 5    0    0    0  119  516   10
# 6    0    0    0    4    0  523

# %% [markdown]
# #### c. Sur les coefficients d'ondelettes de Niveau le plus fin

# %%
t_start = time.time()
model_rf = RandomForestClassifier(n_estimators=200, n_jobs=-1)
model_rf.fit(Coeff_train_n7, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_rf.score(Coeff_test_n7, Y_test_label)
print("Score With RandomForest on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
rf_prediction_label = model_rf.predict(Coeff_test_n7)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(rf_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With RandomForest on Inertial Signals = 71.06, Learning time = 9.46 secondes
#      1    2    3    4    5    6
# 1  465   92   47    0    0    0
# 2   12  366   59    1    4    2
# 3   19   13  314    0    0    0
# 4    0    0    0  200   21   87
# 5    0    0    0  163  427  126
# 6    0    0    0  127   80  322

# %% [markdown]
# #### d. Sur les coefficients d'ondelettes de 1 à 6

# %%
t_start = time.time()
model_rf = RandomForestClassifier(n_estimators=200, n_jobs=-1)
model_rf.fit(Coeff_train_n1_6, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_rf.score(Coeff_test_n1_6, Y_test_label)
print("Score With RandomForest on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
rf_prediction_label = model_rf.predict(Coeff_test_n1_6)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(rf_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With RandomForest on Inertial Signals = 91.38, Learning time = 2.71 secondes
#      1    2    3    4    5    6
# 1  468   10    7    0    0    0
# 2   19  442   18    2    0    0
# 3    9   19  395    0    0    0
# 4    0    0    0  386   53   11
# 5    0    0    0   98  479    3
# 6    0    0    0    5    0  523

# %% [markdown]
# #### e. Sur les coefficients d'ondelettes seuillés

# %%
t_start = time.time()
model_rf = RandomForestClassifier(n_estimators=200, n_jobs=-1)
model_rf.fit(TCoeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_rf.score(TCoeff_test, Y_test_label)
print("Score With RandomForest on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
rf_prediction_label = model_rf.predict(TCoeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(rf_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With RandomForest on Inertial Signals = 93.59, Learning time = 3.71 secondes
#      1    2    3    4    5    6
# 1  483    8    6    0    0    0
# 2    6  456    7    3    0    0
# 3    7    7  407    0    0    0
# 4    0    0    0  373   16    7
# 5    0    0    0  111  516    7
# 6    0    0    0    4    0  523

# %% [markdown]
# #### f. Optimisation
#
# Le paramètre avec la plus grande influence sur le score de prédiction est le nombre d’arbres ($n\_estimators$) à utiliser pour réaliser l’estimation. Pour optimiser ce paramètre, nous avons choisi de découper le jeu de données en 10 parties, donc une 10-fold cross validation. Cela permet d'éviter le sur-ajustement et d’avoir une image plus claire sur le score de prédiction.
#
# Dans le but d'évaluer de façon plus approfondie la performance de RandomForest sur ce jeu de données, nous avons testé une série de combinaisons possibles entre les 3 paramètres qui ont un rôle significatif sur le score de prédiction de cette méthode.<br>
# Il s'agit de : <br>
# * $n\_estimators$ : le nombre d'arbres<br>
# * $max\_depth$ : la profondeur maximale des arbres<br>
# * $max\_features$ : le nombre d’attributs à considérer a chaque split

# %%
# Optimisation du paramètre de pénalisation
# grille de valeurs
ts = time.time()
param=[{"max_depth":list(range(2,11)),
        "n_estimators":list(range(50,250,50)),
        "max_features":list(range(1,50,10))}]

model = GridSearchCV(RandomForestClassifier(verbose=1), param,cv=5,n_jobs=-1)
modelOpt=model.fit(X_train_flatten, Y_train_label)
te = time.time()
print("Temps : %d secondes" %(te-ts))
print("Meilleur score = %f, Meilleur paramètre = %s" % (modelOpt.best_score_,modelOpt.best_params_))
yChap = modelOpt.predict(X_test_flatten)
# matrice de confusion
modelOpt.score(X_test_flatten, Y_test_label)
pd.DataFrame(confusion_matrix(yChap, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:   30.7s finished
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# Temps : 1207 secondes
# Meilleur score = 0.883569, Meilleur paramètre = {'max_depth': 10, 'max_features': 41, 'n_estimators': 200}
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
#      1    2    3    4    5    6
# 1  429   77   40    3    3    0
# 2   30  363   29   24    5    0
# 3   37   30  351    0    0    0
# 4    0    1    0  388   94    0
# 5    0    0    0   76  430    0
# 6    0    0    0    0    0  537

# %% [markdown]
# ### 3.6 Gradient Boosting
#
# L'algorithme Gradient Boosting comme sa version plus performante XGBoost offre un choix important de paramètres à optimiser. Ceux qui doivent être optimisés en premier sont : le nombre d'arbres utilisés pour l'estimation, la profondeur maximale de ces arbres et la taille minimum des feuilles.
#
# La complexité de cette méthode est due principalement au nombre significatif de combinaisons possibles entre les paramètres disponibles pour l'optimisation. Cela nécessite du temps et des ressources. Pour se faire une idée sur la performance de Gradient Boosting sur ce jeu de données, il suffit d'optimiser les deux premiers paramètres énoncés ci-dessus. Le score obtenu pourrait être amélioré en utilisant les autres paramètres, mais cette amélioration ne sera pas marquante.<br>
# Nous avons donc choisi de chercher à optimiser ces deux paramètres pour évaluer la performance de cette méthode et nous avons testé également XGBoost. <br>
# Dans le cadre de ce projet, l'optimisation de Gradient Boosting et XGBoost a été realisée dans le but d'approfondir nos connaissances sur ces méthodes. Cela nous a permis de mieux comprendre le principe de leur fonctionnement et la technique à mettre en place pour les optimiser.

# %% [markdown]
# #### a. Sur données brutes

# %%
t_start = time.time()
model_gb = GradientBoostingClassifier()
model_gb.fit(X_train_flatten, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_gb.score(X_test_flatten, Y_test_label)
print("Score With Gradient Boosting on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
gb_prediction_label = model_gb.predict(X_test_flatten)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(gb_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With RandomForest on Inertial Signals = 87.61, Learning time = 300.18 secondes
#      1    2    3    4    5    6
# 1  479   97   50    0    1    0
# 2    4  350   21   11    7    0
# 3   13   24  349    0    0    0
# 4    0    0    0  405   62    0
# 5    0    0    0   75  462    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### b. Sur coefficients d'ondelettes

# %%
t_start = time.time()
model_gb = GradientBoostingClassifier()
model_gb.fit(Coeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_gb.score(Coeff_test, Y_test_label)
print("Score With Gradient Boosting on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
gb_prediction_label = model_gb.predict(Coeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(gb_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With Gradient Boosting on Inertial Signals = 90.43, Learning time = 440.20 secondes
#      1    2    3    4    5    6
# 1  471   28   26    0    1    0
# 2   21  420   40    4    3    0
# 3    4    8  354    0    0    0
# 4    0   15    0  389   34    0
# 5    0    0    0   98  494    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### c. Sur les coefficients d'ondelettes de Niveau le plus fin

# %%
t_start = time.time()
model_gb = GradientBoostingClassifier()
model_gb.fit(Coeff_train_n7, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_gb.score(Coeff_test_n7, Y_test_label)
print("Score With Gradient Boosting on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
gb_prediction_label = model_gb.predict(Coeff_test_n7)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(gb_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With Gradient Boosting on Inertial Signals = 71.36, Learning time = 563.68 secondes
#      1    2    3    4    5    6
# 1  424   63   46    0    2    0
# 2   47  398   58    0    0    0
# 3   25   10  316    0    0    0
# 4    0    0    0  265   42  141
# 5    0    0    0  143  399   95
# 6    0    0    0   83   89  301

# %% [markdown]
# #### d. Sur les coefficients d'ondelettes de 1 à 6

# %%
t_start = time.time()
model_gb = GradientBoostingClassifier()
model_gb.fit(Coeff_train_n1_6, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_gb.score(Coeff_test_n1_6, Y_test_label)
print("Score With Gradient Boosting on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
gb_prediction_label = model_gb.predict(Coeff_test_n1_6)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(gb_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With Gradient Boosting on Inertial Signals = 89.55, Learning time = 57.94 secondes
#      1    2    3    4    5    6
# 1  469   41   23    0    1    0
# 2   21  407   42    3    6    0
# 3    5    9  355    0    0    0
# 4    1   14    0  391   45    0
# 5    0    0    0   97  480    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### e. Sur les coefficients d'ondelettes seuillés

# %%
t_start = time.time()
model_gb = GradientBoostingClassifier()
model_gb.fit(TCoeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_gb.score(TCoeff_test, Y_test_label)
print("Score With Gradient Boosting on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
gb_prediction_label = model_gb.predict(TCoeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(gb_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With Gradient Boosting on Inertial Signals = 90.23, Learning time = 404.65 secondes
#      1    2    3    4    5    6
# 1  463   26   27    0    0    0
# 2   27  423   36    2    4    0
# 3    6   11  357    0    0    0
# 4    0   11    0  388   37    0
# 5    0    0    0  101  491    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### f. Optimisation

# %%
# Optimisation du paramètre de pénalisation
# grille de valeurs
ts = time.time()
param=[{"max_depth":list(range(2,11)),
        "n_estimators":list(range(50,250,50))
       }]
model = GridSearchCV(GradientBoostingClassifier(verbose=1), param,cv=5,n_jobs=-1)
modelOpt=model.fit(X_train_flatten, Y_train_label)
te = time.time()
print("Temps : %d secondes" %(te-ts))
print("Meilleur score = %f, Meilleur paramètre = %s" % (modelOpt.best_score_,modelOpt.best_params_))
yChap = modelOpt.predict(X_test_flatten)
# matrice de confusion
modelOpt.score(X_test_flatten, Y_test_label)
pd.DataFrame(confusion_matrix(yChap, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
#       Iter       Train Loss   Remaining Time
#          1       10669.1813           24.65m
#          2        8988.9368           24.59m
#          3        7719.7170           24.61m
#          4        6704.8849           24.46m
#          5        5862.1386           24.27m
#          6        5174.1916           24.12m
#          7        4598.8314           24.04m
#          8        4106.9547           23.92m
#          9        3688.4705           23.80m
#         10        3323.6021           23.66m
#         20        1406.3259           22.32m
#         30         720.6868           20.96m
#         40         399.8409           19.67m
#         50         233.1946           18.31m
#         60         136.8358           16.84m
#         70          84.2886           15.30m
#         80          52.7642           13.88m
#         90          33.6953           12.55m
#        100          21.0933           11.29m
#        200           2.4782            0.00s
# ...

# %% [markdown]
# ### 3.7 XGBoost
#
# Comme nous expliquons dans la partie sur le Gradient Boosting, eXtreme Gradient Boosting est une version plus efficace de Gradient Boosting. L'analyse de cette méthode est identique à celle de Gradient Boosting.

# %% [markdown]
# #### a. Sur données brutes

# %%
t_start = time.time()
model_xgb = XGBClassifier(objective='multi:softmax')
model_xgb.fit(X_train_flatten, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_xgb.score(X_test_flatten, Y_test_label)
print("Score With XGBoost on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
xgb_prediction_label = model_xgb.predict(X_test_flatten)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(xgb_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With Gradient Boosting on Inertial Signals = 85.99, Learning time = 399.54 secondes
#      1    2    3    4    5    6
# 1  462  113   55    0    0    0
# 2   19  337   26   10    7    0
# 3   15   21  339    0    0    0
# 4    0    0    0  403   69    0
# 5    0    0    0   78  456    0
# 6    0    0    0    0    0  537

# %% [markdown]
# #### b. Sur coefficients d'ondelettes

# %%
t_start = time.time()
model_xgb.fit(Coeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_xgb.score(Coeff_test, Y_test_label)
print("Score With XGBoost on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
xgb_prediction_label = model_xgb.predict(Coeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(xgb_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With XGBoost on Inertial Signals = 86.70, Learning time = 404.83 secondes
#      1    2    3    4    5    6
# 1  450   47   31    0    1    0
# 2   33  382   56    5    5   19
# 3   13   34  333    0    0    0
# 4    0    8    0  397   43    2
# 5    0    0    0   89  483    6
# 6    0    0    0    0    0  510

# %% [markdown]
# #### c. Sur les coefficients d'ondelettes de Niveau le plus fin

# %%
t_start = time.time()
model_xgb.fit(Coeff_train_n7, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_xgb.score(Coeff_test_n7, Y_test_label)
print("Score With XGBoost on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
xgb_prediction_label = model_xgb.predict(Coeff_test_n7)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(xgb_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With XGBoost on Inertial Signals = 57.82, Learning time = 206.51 secondes
#      1    2    3    4    5    6
# 1  335  103  125    0    0    0
# 2  138  356   76    1    5    3
# 3   23   12  219    0    0    0
# 4    0    0    0  239   79  171
# 5    0    0    0  144  313  121
# 6    0    0    0  107  135  242

# %% [markdown]
# #### d. Sur les coefficients d'ondelettes de 1 à 6

# %%
t_start = time.time()
model_xgb.fit(Coeff_train_n1_6, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_xgb.score(Coeff_test_n1_6, Y_test_label)
print("Score With XGB on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
xgb_prediction_label = model_xgb.predict(Coeff_test_n1_6)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(xgb_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With XGB on Inertial Signals = 86.70, Learning time = 199.65 secondes
#      1    2    3    4    5    6
# 1  452   46   34    0    0    0
# 2   34  385   54    5    5    7
# 3   10   34  332    0    0    0
# 4    0    6    0  392   43    9
# 5    0    0    0   94  484   11
# 6    0    0    0    0    0  510

# %% [markdown]
# #### e. Sur les coefficients d'ondelettes seuillés

# %%
t_start = time.time()
model_xgb.fit(TCoeff_train, Y_train_label)
t_end = time.time()
t_learning = t_end-t_start
score = model_xgb.score(TCoeff_test, Y_test_label)
print("Score With Gradient Boosting on Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
xgb_prediction_label = model_xgb.predict(TCoeff_test)
metadata_svc = {"time_learning" : t_learning, "score" : score}
pd.DataFrame(confusion_matrix(xgb_prediction_label, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Score With Gradient Boosting on Inertial Signals = 86.33, Learning time = 178.30 secondes
#      1    2    3    4    5    6
# 1  448   50   31    0    0    0
# 2   34  380   57    2    4    3
# 3   14   40  332    0    0    0
# 4    0    1    0  394   48    9
# 5    0    0    0   95  480   15
# 6    0    0    0    0    0  510

# %% [markdown]
# #### f. Optimisation
# XGBoost comporte de nombreux paramètres à optimiser. Parmi eux, les plus importants sont la profondeur maximale des arbres, le nombre d'arbres utilisés, la taille minimum des feuilles. De par la présence de nombreux paramètres, l'utilisation d'une recherche sur grille devient rédibitoire, il y a beaucoup trop de combinaisons possibles des paramètres. On pourrait alors imaginer utiliser des méthodes de recherche plus adaptées telles que celle présentées dans l'Annexe de ce calepin.

# %%
# Optimisation du paramètre de pénalisation
# grille de valeurs
ts = time.time()
param=[{"max_depth":list(range(2,11)),
        "n_estimators":list(range(50,250,50))
       }]
model = GridSearchCV(XGBClassifier(verbose=1), param,cv=5,n_jobs=-1)
modelOpt=model.fit(X_train_flatten, Y_train_label)
te = time.time()
print("Temps : %d secondes" %(te-ts))
print("Meilleur score = %f, Meilleur paramètre = %s" % (modelOpt.best_score_,modelOpt.best_params_))
yChap = modelOpt.predict(X_test_flatten)
# matrice de confusion
modelOpt.score(X_test_flatten, Y_test_label)
pd.DataFrame(confusion_matrix(yChap, Y_test_label), index = ACTIVITY_DIC, columns=ACTIVITY_DIC)
# Out:
# Temps : 19610 secondes
# Meilleur score = 0.921790, Meilleur paramètre = {'max_depth': 5, 'n_estimators': 200}
#      1    2    3    4    5    6
# 1  485   57   17    0    0    0
# 2    3  388    6   19    7    0
# 3    8   26  397    0    0    0
# 4    0    0    0  397   59    0
# 5    0    0    0   75  466    0
# 6    0    0    0    0    0  537

# %% [markdown]
# ## 4 Apprentissage des signaux multidimensionnels
# Les différents signaux ne sont pas concaténées en un seul signal mais pris en compte parallèlement.
#
# Les réseaux de neurones sont des modèles interessant de par leur complexité. Théoriquement capable de reproduire toute fonction non-linéaire, leur construction et leur optimisation relèvent presque de compétences artistiques. En effet, l'enchainement de combinaisons linéaires de combinaisons linéaires (répétition voulue) transforme cette méthode en véritable boite noire. De par le nombre de paramètres optimisable, une recherche sur grille devient impossible et il faut avoir recours à des méthodes d'optimisation plus poussées comme expliqué dans la partie Annexe. Enfin, de nombreux types de réseaux de neurones existent aujourd'hui ce qui rend le choix d'un bon modèle  compliqué. Nous nous concentrons ici uniquement sur les perceptrons multi-couches fournient par la librairie scikit-learn. L'optimisation des paramètres est également sommaire car les performances des méthodes linéaires face aux méthodes non-linéaires ne semble pas justifié une étude approfondie de paramètres optimaux.
#
# ### 4.1 Perceptron multichouche
# **Q** Expliciter les choix des paramètres et donc la structure du réseau.

# %%
n_hidden = 32

timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = 6

model_base_mlp =km.Sequential()
model_base_mlp.add(kl.Dense(n_hidden, input_shape=(timesteps, input_dim),  activation = "relu"))
model_base_mlp.add(kl.Reshape((timesteps*n_hidden,) , input_shape= (timesteps, n_hidden)  ))
model_base_mlp.add(kl.Dense(n_classes, activation='softmax'))

model_base_mlp.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

t_start = time.time()
model_base_mlp.fit(X_train,  Y_train_dummies, batch_size=batch_size, validation_data=(X_test, Y_test_dummies), epochs=epochs)
t_end = time.time()
t_learning = t_end-t_start

score = model_base_mlp.evaluate(X_test, Y_test_dummies)[1] 
print("Score With Simple MLP on Multidimensional Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
metadata_mlp = {"time_learning" : t_learning, "score" : score}
base_mlp_prediction = model_base_mlp.predict(X_test)

my_confusion_matrix(Y_test_dummies, base_mlp_prediction)

# %%
model_base_mlp.summary()

# %% [markdown]
# ### 4.2 *Long Short Time Memory (LSTM)*
# Test d'un réseau avec couche LSTM avec l'idée d'appréhender la structure temporelle des données.

# %%
n_hidden = 32
#default stateful = False

timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = 6

batch_size=64
#else:
model_base_lstm =km.Sequential()
model_base_lstm.add(kl.LSTM(n_hidden, input_shape=(timesteps, input_dim)))
model_base_lstm.add(kl.Dense(n_classes, activation='softmax'))

model_base_lstm.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model_base_lstm.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-25cac39ce13e> in <module>()
#       2 #default stateful = False
#       3
# ----> 4 timesteps = len(X_train[0])
#       5 input_dim = len(X_train[0][0])
#       6 n_classes = 6
#
# NameError: name 'X_train' is not defined

# %%
# Default shuffle = True Meilleur avec Shuffle m True
t_start = time.time()
model_base_lstm.fit(X_train,  Y_train_dummies, batch_size=batch_size, validation_data=(X_test, Y_test_dummies), epochs=epochs, shuffle=False)
t_end = time.time()
t_learning = t_end-t_start

score = model_base_lstm.evaluate(X_test, Y_test_dummies)[1] 
print("Score With Simple MLP on Multidimensional Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
metadata_lstm = {"time_learning" : t_learning, "score" : score}
base_lstm_prediction = model_base_lstm.predict(X_test)

my_confusion_matrix(Y_test_dummies, base_lstm_prediction)

# %% [markdown]
# ### 3.3 Réseau avec couche convolutionelle 1D (*ConvNet*)

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = 6

#else:
model_base_conv_1D =km.Sequential()
model_base_conv_1D.add(kl.Conv1D(32, 9, activation='relu', input_shape=(timesteps, input_dim)))
model_base_conv_1D.add(kl.MaxPooling1D(pool_size=3))
model_base_conv_1D.add(kl.Flatten())
model_base_conv_1D.add(kl.Dense(n_classes, activation='softmax'))
model_base_conv_1D.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

t_start = time.time()
model_base_conv_1D.fit(X_train,  Y_train_dummies, batch_size=batch_size, validation_data=(X_test, Y_test_dummies), epochs=epochs)
t_end = time.time()
t_learning = t_end-t_start

score = model_base_conv_1D.evaluate(X_test, Y_test_dummies)[1] 
print("Score With Conv on Multidimensional Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
metadata_conv = {"time_learning" : t_learning, "score" : score}
base_conv_1D_prediction = model_base_conv_1D.predict(X_test)

my_confusion_matrix(Y_test_dummies, base_conv_1D_prediction)

# %%
model_base_conv_1D.summary()

# %% [markdown]
# ### 4.3 Réseau avec couche convolutionelle 2D (*ConvNet*)

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = 6

X_train_conv = X_train.reshape(N_train, timesteps, input_dim, 1)
X_test_conv = X_test.reshape(N_test, timesteps, input_dim, 1)

#else:
model_base_conv_2D =km.Sequential()
model_base_conv_2D.add(kl.Conv2D(32, (3, 9), activation='relu', input_shape=(timesteps, input_dim, 1)))
model_base_conv_2D.add(kl.MaxPooling2D(pool_size=(2, 1)))
model_base_conv_2D.add(kl.Flatten())
model_base_conv_2D.add(kl.Dense(n_classes, activation='softmax'))
model_base_conv_2D.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

t_start = time.time()
model_base_conv_2D.fit(X_train_conv,  Y_train_dummies, batch_size=batch_size, validation_data=(X_test_conv, Y_test_dummies), epochs=epochs)
t_end = time.time()
t_learning = t_end-t_start

score = model_base_conv_2D.evaluate(X_test_conv, Y_test_dummies)[1] 
print("Score With Conv on Multidimensional Inertial Signals = %.2f, Learning time = %.2f secondes" %(score*100, t_learning) )
metadata_conv = {"time_learning" : t_learning, "score" : score}
base_conv_2D_prediction = model_base_conv_2D.predict(X_test_conv)

my_confusion_matrix(Y_test_dummies, base_conv_2D_prediction)

# %%
model_base_conv_2D.summary()

# %% [markdown]
# **Objectif** trouver la meilleure architecture.
#
# **Attention au sur-apprentissage** A force de rechercher la meilleure architecture en minimisant l'erreur sur l'échantillon test, celle finalement trouvée peut y être très adaptée réduisant ainsi la capacité de généralisation. Il serait prudent de multiplier le découpage de l'échantillon par validation croisée *Monte Carlo*.
