# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from sklearn.preprocessing import scale
from sklearn.svm import SVC, LinearSVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

import pickle
import os
import Annex

# %%
import imp
imp.reload(Annex)
# Out:
# <module 'Annex' from 'C:\\Users\\Quentin\\Documents\\INSA\\5GMM\\HAR\\Annex.py'>

# %%
Xtrain=pd.read_table("X_train.txt",sep='\s+',header=None)
ytrain=pd.read_table("y_train.txt",sep='\s+',header=None,names=('y'))
Xtest=pd.read_table("X_test.txt",sep='\s+',header=None)
ytest=pd.read_table("y_test.txt",sep='\s+',header=None,names=('y'))
ytrain=ytrain["y"]
ytest=ytest["y"]
LABELS = ["WALKING","WALKING UPSTAIRS","WALKING DOWNSTAIRS","SITTING","STANDING","LAYING"]

scaler=scale()
scaler.fit(Xtrain)
Xtrain=scaler.transform(Xtrain)
Xtest=scaler.transform(Xtest)

path='./results/Resultats.pickle'
if os.path.exists(path):
    Resultats=pickle.load(open(path, 'rb'))
else:
    Resultats=Annex.Results()
Resultats.say_hello()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-9892863d4819> in <module>()
#       7 LABELS = ["WALKING","WALKING UPSTAIRS","WALKING DOWNSTAIRS","SITTING","STANDING","LAYING"]
#       8
# ----> 9 scaler=scale.fit(Xtrain)
#      10 Xtrain=scaler.transform(Xtrain)
#      11 Xtest=scaler.transform(Xtest)
#
# AttributeError: 'function' object has no attribute 'fit'

# %% [markdown]
# # Optimisation

# %%
Resultats.optimize(Xtrain,ytrain,nb_epoch=2,method='all',goal='max',coef_selection=0.2)
f=open('./results/Resultats.pickle', 'wb')
pickle.dump(Resultats,f)
f.close()
# Out:
# I want to improve myself!
# I am too young to be optimized, let me try some randomness first.
# <class 'sklearn.svm.classes.SVC'>
# Running SVC with parameters: {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 55.495000000000005}
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]Score: 9.449e-01
#
# <class 'sklearn.svm.classes.LinearSVC'>
# Running LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr', 'loss': 'squared_hinge', 'intercept_scaling': 1, 'fit_intercept': False, 'dual': False, 'class_weight': None, 'C': 80.219999999999999}
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]Score: 9.462e-01
#
# <class 'sklearn.svm.classes.SVC'>
# Running SVC with parameters: {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]Score: 8.496e-01
#
# <class 'sklearn.linear_model.logistic.LogisticRegression'>
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 300, 'intercept_scaling': 1, 'fit_intercept': False, 'dual': True, 'class_weight': None, 'C': 1.5}
# An error occured with this configuration.
# Score: nan
#
# <class 'sklearn.linear_model.logistic.LogisticRegression'>
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'newton-cg', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 300, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 1.6000000000000001}
# An error occured with this configuration.
# Score: nan
#
# <class 'sklearn.svm.classes.LinearSVC'>
# Running LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l1', 'multi_class': 'crammer_singer', 'loss': 'hinge', 'intercept_scaling': 1, 'fit_intercept': False, 'dual': True, 'class_weight': None, 'C': 0.0}
# [LibLinear]An error occured with this configuration.
# Score: nan
#
# <class 'sklearn.svm.classes.LinearSVC'>
# Running LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l2', 'multi_class': 'crammer_singer', 'loss': 'squared_hinge', 'intercept_scaling': 1, 'fit_intercept': False, 'dual': False, 'class_weight': None, 'C': 30.770000000000003}
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Score: 9.401e-01
#
# <class 'sklearn.svm.classes.LinearSVC'>
# Running LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l1', 'multi_class': 'crammer_singer', 'loss': 'squared_hinge', 'intercept_scaling': 1, 'fit_intercept': False, 'dual': False, 'class_weight': None, 'C': 70.329999999999998}
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Score: 9.401e-01
#
# <class 'sklearn.svm.classes.SVC'>
# Running SVC with parameters: {'tol': 0.001, 'shrinking': False, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 4, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.85000000000000009}
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]Score: 9.526e-01
#
# <class 'sklearn.linear_model.logistic.LogisticRegression'>
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'newton-cg', 'random_state': None, 'penalty': 'l2', 'multi_class': 'multinomial', 'max_iter': 300, 'intercept_scaling': 1, 'fit_intercept': False, 'dual': False, 'class_weight': None, 'C': 0.5}
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s finished
# Score: 9.464e-01
#
#
# Epoch 1
# I selected the 2 best solutions I know.
# <class 'int'>
# Mutation!
# Evaluation...
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'lbfgs', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 300, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 0.30000000000000004}
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.1s remaining:    0.0s
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:718: UserWarning: lbfgs failed to converge. Increase the number of iterations.
#   warnings.warn("lbfgs failed to converge. Increase the number "
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    7.1s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    6.4s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.0s remaining:    0.0s
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:718: UserWarning: lbfgs failed to converge. Increase the number of iterations.
#   warnings.warn("lbfgs failed to converge. Increase the number "
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    7.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.9s remaining:    0.0s
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:718: UserWarning: lbfgs failed to converge. Increase the number of iterations.
#   warnings.warn("lbfgs failed to converge. Increase the number "
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    7.3s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.8s remaining:    0.0s
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:718: UserWarning: lbfgs failed to converge. Increase the number of iterations.
#   warnings.warn("lbfgs failed to converge. Increase the number "
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    7.6s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.9s remaining:    0.0s
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:718: UserWarning: lbfgs failed to converge. Increase the number of iterations.
#   warnings.warn("lbfgs failed to converge. Increase the number "
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    7.4s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.6s remaining:    0.0s
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:718: UserWarning: lbfgs failed to converge. Increase the number of iterations.
#   warnings.warn("lbfgs failed to converge. Increase the number "
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    8.0s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.3s remaining:    0.0s
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:718: UserWarning: lbfgs failed to converge. Increase the number of iterations.
#   warnings.warn("lbfgs failed to converge. Increase the number "
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    7.8s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.6s remaining:    0.0s
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:718: UserWarning: lbfgs failed to converge. Increase the number of iterations.
#   warnings.warn("lbfgs failed to converge. Increase the number "
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    7.0s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    7.5s finished
# Score: 9.447e-01
#
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'newton-cg', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 300, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 1.7000000000000002}
# An error occured with this configuration.
# Score: nan
#
#
# Epoch 2
# I selected the 2 best solutions I know.
# <class 'int'>
# Mutation!
# Evaluation...
# Running LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr', 'loss': 'squared_hinge', 'intercept_scaling': 1, 'fit_intercept': False, 'dual': True, 'class_weight': None, 'C': 15.935}
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]Score: 9.473e-01
#
# Running SVC with parameters: {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'precomputed', 'gamma': 'auto', 'degree': 9, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.70000000000000007}
# An error occured with this configuration.
# Score: nan
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
#Resultats.run(Xtrain,ytrain,method,param)
Resultats.random_start(Xtrain,ytrain,nb_run=10)
f=open('./results/Resultats.pickle', 'wb')
pickle.dump(Resultats,f)
f.close()
# Out:
# <class 'sklearn.svm.classes.LinearSVC'>
# Running LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr', 'loss': 'hinge', 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 0.45000000000000001}
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Score: 9.504e-01
#
# <class 'sklearn.linear_model.logistic.LogisticRegression'>
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 300, 'intercept_scaling': 1, 'fit_intercept': False, 'dual': False, 'class_weight': None, 'C': 0.30000000000000004}
# convergence after 167 epochs took 11 seconds
# convergence after 186 epochs took 11 seconds
# convergence after 189 epochs took 10 seconds
# convergence after 219 epochs took 13 seconds
# convergence after 225 epochs took 13 seconds
# convergence after 168 epochs took 9 seconds
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.1min finished
# convergence after 175 epochs took 10 seconds
# convergence after 181 epochs took 10 seconds
# convergence after 190 epochs took 10 seconds
# convergence after 215 epochs took 12 seconds
# convergence after 218 epochs took 12 seconds
# convergence after 178 epochs took 10 seconds
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.1min finished
# convergence after 162 epochs took 9 seconds
# convergence after 181 epochs took 9 seconds
# convergence after 181 epochs took 10 seconds
# convergence after 219 epochs took 12 seconds
# convergence after 222 epochs took 12 seconds
# convergence after 183 epochs took 10 seconds
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.0min finished
# convergence after 175 epochs took 10 seconds
# convergence after 181 epochs took 10 seconds
# convergence after 193 epochs took 10 seconds
# convergence after 224 epochs took 12 seconds
# convergence after 230 epochs took 13 seconds
# convergence after 175 epochs took 9 seconds
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.1min finished
# convergence after 171 epochs took 10 seconds
# convergence after 181 epochs took 10 seconds
# convergence after 169 epochs took 9 seconds
# convergence after 218 epochs took 12 seconds
# convergence after 223 epochs took 12 seconds
# convergence after 164 epochs took 9 seconds
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.0min finished
# convergence after 166 epochs took 9 seconds
# convergence after 192 epochs took 10 seconds
# convergence after 191 epochs took 11 seconds
# convergence after 218 epochs took 12 seconds
# convergence after 222 epochs took 12 seconds
# convergence after 170 epochs took 9 seconds
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.1min finished
# convergence after 165 epochs took 9 seconds
# convergence after 182 epochs took 10 seconds
# convergence after 189 epochs took 11 seconds
# convergence after 220 epochs took 12 seconds
# convergence after 222 epochs took 12 seconds
# convergence after 178 epochs took 9 seconds
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.1min finished
# convergence after 165 epochs took 10 seconds
# convergence after 177 epochs took 9 seconds
# convergence after 187 epochs took 11 seconds
# convergence after 219 epochs took 12 seconds
# convergence after 223 epochs took 12 seconds
# convergence after 168 epochs took 9 seconds
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.0min finished
# convergence after 167 epochs took 9 seconds
# convergence after 186 epochs took 10 seconds
# convergence after 194 epochs took 11 seconds
# convergence after 221 epochs took 12 seconds
# convergence after 226 epochs took 12 seconds
# convergence after 167 epochs took 9 seconds
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.1min finished
# convergence after 170 epochs took 10 seconds
# convergence after 188 epochs took 10 seconds
# convergence after 191 epochs took 10 seconds
# convergence after 221 epochs took 12 seconds
# convergence after 227 epochs took 13 seconds
# convergence after 161 epochs took 8 seconds
# Score: 9.432e-01
#
# <class 'sklearn.svm.classes.LinearSVC'>
# Running LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l2', 'multi_class': 'crammer_singer', 'loss': 'hinge', 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 15.935}
# [LibLinear]
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.0min finished
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Score: 9.419e-01
#
# <class 'sklearn.linear_model.logistic.LogisticRegression'>
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'newton-cg', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 300, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': True, 'class_weight': None, 'C': 1.9000000000000001}
# An error occured with this configuration.
# Score: nan
#
# <class 'sklearn.svm.classes.LinearSVC'>
# Running LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l2', 'multi_class': 'crammer_singer', 'loss': 'hinge', 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 0.25}
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Score: 9.504e-01
#
# <class 'sklearn.svm.classes.SVC'>
# Running SVC with parameters: {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'linear', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]Score: 9.527e-01
#
# <class 'sklearn.linear_model.logistic.LogisticRegression'>
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'saga', 'random_state': None, 'penalty': 'l2', 'multi_class': 'multinomial', 'max_iter': 300, 'intercept_scaling': 1, 'fit_intercept': False, 'dual': True, 'class_weight': None, 'C': 1.2000000000000002}
# An error occured with this configuration.
# Score: nan
#
# <class 'sklearn.svm.classes.SVC'>
# Running SVC with parameters: {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'poly', 'gamma': 'auto', 'degree': 3, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 0.80000000000000004}
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]Score: 8.915e-01
#
# <class 'sklearn.svm.classes.LinearSVC'>
# Running LinearSVC with parameters: {'tol': 0.0001, 'penalty': 'l1', 'multi_class': 'crammer_singer', 'loss': 'squared_hinge', 'intercept_scaling': 1, 'fit_intercept': False, 'dual': False, 'class_weight': None, 'C': 0.10000000000000001}
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]Score: 9.455e-01
#
# <class 'sklearn.linear_model.logistic.LogisticRegression'>
# Running LogisticRegression with parameters: {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l2', 'multi_class': 'ovr', 'max_iter': 300, 'intercept_scaling': 1, 'fit_intercept': False, 'dual': False, 'class_weight': None, 'C': 0.0}
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:748: RuntimeWarning: divide by zero encountered in double_scalars
#   alpha = 1. / C
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:304: RuntimeWarning: invalid value encountered in double_scalars
#   if step_size * alpha_scaled == 1:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #1. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.
# Exception ignored in: 'sklearn.linear_model.sag_fast.raise_infinite_error'
# ValueError: Floating-point under-/overflow occurred at epoch #5. Lowering the step_size or scaling the input data with StandardScaler or MinMaxScaler might help.

# %% [markdown]
# ## Meilleurs résultats

# %%
print(Annex.Results(Resultats.bests(nb=5)))
# Out:
# 5 Results:
# SVC:
# Parameters:
# {'tol': 0.001, 'shrinking': True, 'probability': False, 'kernel': 'sigmoid', 'gamma': 'auto', 'degree': 5, 'coef0': 0.0, 'class_weight': None, 'cache_size': 200, 'C': 55.495000000000005}
# Score: nan
#
# LinearSVC:
# Parameters:
# {'tol': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr', 'loss': 'squared_hinge', 'intercept_scaling': 1, 'fit_intercept': False, 'dual': False, 'class_weight': None, 'C': 80.219999999999999}
# Score: 9.473e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'sag', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 300, 'intercept_scaling': 1, 'fit_intercept': False, 'dual': True, 'class_weight': None, 'C': 1.5}
# Score: 9.447e-01
#
# LogisticRegression:
# Parameters:
# {'tol': 0.0001, 'solver': 'newton-cg', 'random_state': None, 'penalty': 'l1', 'multi_class': 'ovr', 'max_iter': 300, 'intercept_scaling': 1, 'fit_intercept': True, 'dual': False, 'class_weight': None, 'C': 1.6000000000000001}
# Score: nan
#
# LinearSVC:
# Parameters:
# {'tol': 0.0001, 'penalty': 'l1', 'multi_class': 'crammer_singer', 'loss': 'hinge', 'intercept_scaling': 1, 'fit_intercept': False, 'dual': True, 'class_weight': None, 'C': 0.0}
# Score: nan

# %% [markdown]
# ## SVM Linéaire

# %% [raw]
# param=[{"penalty":['l2','l1'],
#         "loss":['squared_hinge','hinge'],
#         "dual":[True,False],
#         "tol":[0.0001],
#         "C":np.concatenate([np.linspace(0,1,21),np.linspace(1.1,100,21)]),
#         "multi_class":['ovr','cramer_singer'],
#         "fit_intercept":[True,False],
#         "intercept_scaling":[1],
#         "class_weight":[None]
#         }]
# from sklearn.model_selection import ParameterGrid
# len(ParameterGrid(param))
# P={'C': 0.1,
#  'class_weight': None,
#  'dual': True,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'loss': 'squared_hinge',
#  'multi_class': 'cramer_singer',
#  'penalty': 'l2',
#  'tol': 0.0001}
#
# grid=list(ParameterGrid(param))
# grid[66]

# %% [raw]
# method = LinearSVC
# param={"penalty":['l2'],
#         "loss":['squared_hinge'],
#         "dual":[True],
#         "tol":[0.0001],
#         "C":[0.1,0.5,0.75,1.5,2,3,10,0.9,1,1.1],
#         "multi_class":['ovr'],
#         "fit_intercept":[True],
#         "intercept_scaling":[1],
#         "class_weight":[None]
#         }
# param["loss"]

# %% [markdown]
#  ## SVM Gaussien

# %% [raw]
# method=SVC
# param=[{"C":[0.5,0.75,1,1.5,2],
#         "kernel":['rbf'],#,'linear','poly', 'sigmoid', 'precomputed'
#         "degree":[3],
#         "gamma":['auto'],
#         "coef0":[0.0],
#         "shrinking":[True],
#         "probability":[False],
#         "tol":[0.001],
#         "cache_size":[200],
#         "class_weight":[None],
#       }]
